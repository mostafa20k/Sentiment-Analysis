# %%
import json
import gzip
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence
from torchtext.vocab import build_vocab_from_iterator
from torchtext.data.utils import get_tokenizer
from sklearn.metrics import accuracy_score
import random
from collections import Counter
from transformers import BertTokenizer
import numpy as np
# Out:
# /usr/local/lib/python3.10/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/data/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
import pandas as pd

# %%
# !wget 'https://datarepo.eng.ucsd.edu/mcauley_group/data/amazon_v2/categoryFilesSmall/Musical_Instruments_5.json.gz'
# Out:
# --2024-06-11 08:20:40--  https://datarepo.eng.ucsd.edu/mcauley_group/data/amazon_v2/categoryFilesSmall/Musical_Instruments_5.json.gz
# Resolving datarepo.eng.ucsd.edu (datarepo.eng.ucsd.edu)... 132.239.8.30
# Connecting to datarepo.eng.ucsd.edu (datarepo.eng.ucsd.edu)|132.239.8.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39356138 (38M) [application/x-gzip]
# Saving to: ‘Musical_Instruments_5.json.gz’
#
# Musical_Instruments 100%[===================>]  37.53M  6.91MB/s    in 5.4s
#
# 2024-06-11 08:20:47 (6.91 MB/s) - ‘Musical_Instruments_5.json.gz’ saved [39356138/39356138]

# %%
# !wget 'imdb.csv' 'https://huggingface.co/datasets/scikit-learn/imdb/resolve/main/IMDB%20Dataset.csv?download=true'
# Out:
# --2024-06-11 08:20:47--  http://imdb.csv/
# Resolving imdb.csv (imdb.csv)... failed: Name or service not known.
# wget: unable to resolve host address ‘imdb.csv’
# --2024-06-11 08:20:47--  https://huggingface.co/datasets/scikit-learn/imdb/resolve/main/IMDB%20Dataset.csv?download=true
# Resolving huggingface.co (huggingface.co)... 54.230.71.56, 54.230.71.103, 54.230.71.2, ...
# Connecting to huggingface.co (huggingface.co)|54.230.71.56|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/77/fa/77fa70b48eef1c98bf08d7b3e43b710623c24c69b4f78d4484f43c3361e9d2af/dfc447764f82be365fa9c2beef4e8df89d3919e3da95f5088004797d79695aa2?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27IMDB%2520Dataset.csv%3B+filename%3D%22IMDB+Dataset.csv%22%3B&response-content-type=text%2Fcsv&Expires=1718353247&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=XdySusJuQvn2ZdPg%7EHYVrqeAVsvUuNmziN6vPp4tNoiump8kmtE7qtuFIG84DrrRKSMDdvR0HGzKskiL876Vf4BiGQUpmh51iQVUYHyq3rNqMMH8JcABo9wke%7EmRbjBgJcjY3fFUC5kJIXlwMT0FM5%7EjqSGKmy%7EOI4B1yNVbb0ARWNbxWk3UO99cteN24Ye7klI0jrkyjd%7ErDSVwT1mqfQ%7Eo75u1mjobPl98QsKOUaVmI3nLKLMu25DzaCTWvgbqF0W7IAIs6guJru1HXoU8VIQQcS8JBlFJl6tVkjIZdfCPiNyR4BbVQb8eZWymuMlYqs6y0J8zfKZX4f3I9rvd%7Eg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-06-11 08:20:47--  https://cdn-lfs.huggingface.co/repos/77/fa/77fa70b48eef1c98bf08d7b3e43b710623c24c69b4f78d4484f43c3361e9d2af/dfc447764f82be365fa9c2beef4e8df89d3919e3da95f5088004797d79695aa2?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27IMDB%2520Dataset.csv%3B+filename%3D%22IMDB+Dataset.csv%22%3B&response-content-type=text%2Fcsv&Expires=1718353247&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=XdySusJuQvn2ZdPg%7EHYVrqeAVsvUuNmziN6vPp4tNoiump8kmtE7qtuFIG84DrrRKSMDdvR0HGzKskiL876Vf4BiGQUpmh51iQVUYHyq3rNqMMH8JcABo9wke%7EmRbjBgJcjY3fFUC5kJIXlwMT0FM5%7EjqSGKmy%7EOI4B1yNVbb0ARWNbxWk3UO99cteN24Ye7klI0jrkyjd%7ErDSVwT1mqfQ%7Eo75u1mjobPl98QsKOUaVmI3nLKLMu25DzaCTWvgbqF0W7IAIs6guJru1HXoU8VIQQcS8JBlFJl6tVkjIZdfCPiNyR4BbVQb8eZWymuMlYqs6y0J8zfKZX4f3I9rvd%7Eg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 13.33.183.73, 13.33.183.109, 13.33.183.105, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|13.33.183.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66212309 (63M) [text/csv]
# Saving to: ‘IMDB Dataset.csv?download=true’
#
# IMDB Dataset.csv?do 100%[===================>]  63.14M  13.5MB/s    in 5.4s
#
# 2024-06-11 08:20:54 (11.8 MB/s) - ‘IMDB Dataset.csv?download=true’ saved [66212309/66212309]
#
# FINISHED --2024-06-11 08:20:54--
# Total wall clock time: 7.0s
# Downloaded: 1 files, 63M in 5.4s (11.8 MB/s)

# %%
# !mv '/content/IMDB Dataset.csv?download=true' '/content/IMDB Dataset.csv'

# %%
def load_data(filepath):
    with gzip.open(filepath, 'rt', encoding='utf-8') as f:
        data = [json.loads(line) for line in f]
    return data

data = load_data('/content/Musical_Instruments_5.json.gz')

# %%
len(data)
# Out:
# 231392

# %% [markdown]
# # **Torch Tokenizer**

# %%
tokenizer = get_tokenizer("basic_english")
def yield_tokens(data):
    for entry in data:
      if 'reviewText' in entry:
        yield tokenizer(entry['reviewText'])
vocab = build_vocab_from_iterator(yield_tokens(data), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])
def text_pipeline(text):
    return vocab(tokenizer(text))

labels = [entry['overall'] for entry in data if 'reviewText' in entry]
texts = [text_pipeline(entry['reviewText']) for entry in data if 'reviewText' in entry]

# %% [markdown]
# # **Bert Tokenizer**

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
def yield_tokens(data):
    for entry in data:
      if 'reviewText' in entry:
        yield tokenizer.tokenize(entry['reviewText'])
vocab = tokenizer.get_vocab()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
def text_pipeline(text):
    return tokenizer.encode(text, add_special_tokens=True, max_length=512, truncation=True, padding='max_length')

labels = [entry['overall'] for entry in data if 'reviewText' in entry]
texts = [text_pipeline(entry['reviewText']) for entry in data if 'reviewText' in entry]

# %% [markdown]
# # **Data Loading**

# %%
class ReviewsDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            'text': torch.tensor(self.texts[idx], dtype=torch.long),
            'label': torch.tensor(self.labels[idx], dtype=torch.long)
        }

dataset = ReviewsDataset(texts, labels)

# %%
def collate_fn(batch):
    texts = [item['text'] for item in batch]
    labels = [item['label'] for item in batch]
    texts_padded = pad_sequence(texts, batch_first=True, padding_value=0)
    labels_tensor = torch.tensor(labels, dtype=torch.long)
    return texts_padded, labels_tensor

# %%
# Split the dataset into training and testing sets
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# # **LSTM**

# %%
import torch
import torch.nn as nn

class RNNModel(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm1 = nn.LSTM(embed_size, lstm_units, batch_first=True)
        # self.dropout = nn.Dropout(0.25)
        self.lstm2 = nn.LSTM(lstm_units, lstm_units, batch_first=True)
        self.fc1 = nn.Linear(lstm_units, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm1(x)
        # x = self.dropout(x)
        x, _ = self.lstm2(x)
        x = x[:, -1, :]  # Taking only the last output
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model = RNNModel(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# RNNModel(
#   (embedding): Embedding(112680, 200)
#   (lstm1): LSTM(200, 128, batch_first=True)
#   (lstm2): LSTM(128, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 20
model.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 0.9556, Train Accuracy: 0.6995
# Epoch 2/20, Loss: 0.7966, Train Accuracy: 0.7079
# Epoch 3/20, Loss: 0.6546, Train Accuracy: 0.7434
# Epoch 4/20, Loss: 0.5750, Train Accuracy: 0.7761
# Epoch 5/20, Loss: 0.5100, Train Accuracy: 0.8049
# Epoch 6/20, Loss: 0.4478, Train Accuracy: 0.8330
# Epoch 7/20, Loss: 0.3933, Train Accuracy: 0.8578
# Epoch 8/20, Loss: 0.3490, Train Accuracy: 0.8762
# Epoch 9/20, Loss: 0.3128, Train Accuracy: 0.8907
# Epoch 10/20, Loss: 0.2846, Train Accuracy: 0.9010
# Epoch 11/20, Loss: 0.2635, Train Accuracy: 0.9091
# Epoch 12/20, Loss: 0.2444, Train Accuracy: 0.9165
# Epoch 13/20, Loss: 0.2304, Train Accuracy: 0.9216
# Epoch 14/20, Loss: 0.2179, Train Accuracy: 0.9259
# Epoch 15/20, Loss: 0.2140, Train Accuracy: 0.9269
# Epoch 16/20, Loss: 0.1996, Train Accuracy: 0.9324
# Epoch 17/20, Loss: 0.1885, Train Accuracy: 0.9364
# Epoch 18/20, Loss: 0.1840, Train Accuracy: 0.9379
# Epoch 19/20, Loss: 0.1774, Train Accuracy: 0.9402
# Epoch 20/20, Loss: 0.1726, Train Accuracy: 0.9425
# Test Loss: 1.0677, Test Accuracy: 0.7416

# %% [markdown]
# # **Data Balance**

# %% [markdown]
# # **Balanced Data**

# %%
# Count the occurrences of each class
class_counts = Counter(labels)
print(class_counts)
# Determine the size of the minority class
min_class_size = min(class_counts.values())

# Define the maximum desired size for each class
max_class_size = min_class_size

# Sample indices for each class to balance the dataset
balanced_indices = []
for label in class_counts:
    indices = [i for i, l in enumerate(labels) if l == label]
    if len(indices) > max_class_size:
        indices = random.sample(indices, max_class_size)
    balanced_indices.extend(indices)

# Create balanced dataset
balanced_texts = [texts[i] for i in balanced_indices]
balanced_labels = [labels[i] for i in balanced_indices]
balanced_dataset = ReviewsDataset(balanced_texts, balanced_labels)
train_balanced_size = int(0.8 * len(balanced_dataset))
test_balanced_size = len(balanced_dataset) - train_balanced_size
train_balanced, test_balanced = random_split(balanced_dataset, [train_balanced_size, test_balanced_size])

train_balancedloader = DataLoader(train_balanced, batch_size=64, shuffle=True, collate_fn=collate_fn)
test_balancedloader = DataLoader(test_balanced, batch_size=64, shuffle=False, collate_fn=collate_fn)
# Out:
# Counter({5.0: 161798, 4.0: 38776, 3.0: 16029, 1.0: 7465, 2.0: 7276})

# %%
class_counts = Counter(balanced_labels)
print(class_counts)
# Out:
# Counter({5.0: 7276, 4.0: 7276, 1.0: 7276, 3.0: 7276, 2.0: 7276})

# %% [markdown]
# # **Balanced LSTM**

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 20
model.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.6099, Train Accuracy: 0.1996
# Epoch 2/20, Loss: 1.6089, Train Accuracy: 0.2004
# Epoch 3/20, Loss: 1.6077, Train Accuracy: 0.1993
# Epoch 4/20, Loss: 1.6056, Train Accuracy: 0.2047
# Epoch 5/20, Loss: 1.5882, Train Accuracy: 0.2267
# Epoch 6/20, Loss: 1.3318, Train Accuracy: 0.4239
# Epoch 7/20, Loss: 1.1183, Train Accuracy: 0.5249
# Epoch 8/20, Loss: 0.9673, Train Accuracy: 0.5974
# Epoch 9/20, Loss: 0.8263, Train Accuracy: 0.6727
# Epoch 10/20, Loss: 0.7048, Train Accuracy: 0.7351
# Epoch 11/20, Loss: 0.5939, Train Accuracy: 0.7873
# Epoch 12/20, Loss: 0.5105, Train Accuracy: 0.8250
# Epoch 13/20, Loss: 0.4412, Train Accuracy: 0.8535
# Epoch 14/20, Loss: 0.3761, Train Accuracy: 0.8794
# Epoch 15/20, Loss: 0.3361, Train Accuracy: 0.8939
# Epoch 16/20, Loss: 0.3007, Train Accuracy: 0.9069
# Epoch 17/20, Loss: 0.2774, Train Accuracy: 0.9150
# Epoch 18/20, Loss: 0.2567, Train Accuracy: 0.9222
# Epoch 19/20, Loss: 0.2362, Train Accuracy: 0.9282
# Epoch 20/20, Loss: 0.2235, Train Accuracy: 0.9326
# Test Loss: 2.0590, Test Accuracy: 0.4955

# %%
import torch
import torch.nn as nn

class RNNModel2(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel2, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm1 = nn.LSTM(embed_size, lstm_units, batch_first=True)
        # self.dropout = nn.Dropout(0.25)
        self.lstm2 = nn.LSTM(lstm_units, lstm_units, batch_first=True)
        self.fc1 = nn.Linear(lstm_units, hidden_size)
        #self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm1(x)
        # x = self.dropout(x)
        x, _ = self.lstm2(x)
        x = torch.mean(x, dim=1)
        x = self.fc1(x)
        # x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model2 = RNNModel2(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model2.to(device)
# Out:
# RNNModel2(
#   (embedding): Embedding(30522, 200)
#   (lstm1): LSTM(200, 128, batch_first=True)
#   (lstm2): LSTM(128, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %% [markdown]
# # Bert Tokenizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model2.parameters(), lr=0.001)

num_epochs = 20
model2.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model2(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model2.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model2(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.5541, Train Accuracy: 0.2695
# Epoch 2/20, Loss: 1.4804, Train Accuracy: 0.3162
# Epoch 3/20, Loss: 1.2816, Train Accuracy: 0.4111
# Epoch 4/20, Loss: 1.1684, Train Accuracy: 0.4688
# Epoch 5/20, Loss: 1.0808, Train Accuracy: 0.5159
# Epoch 6/20, Loss: 0.9961, Train Accuracy: 0.5634
# Epoch 7/20, Loss: 0.9144, Train Accuracy: 0.6064
# Epoch 8/20, Loss: 0.8325, Train Accuracy: 0.6491
# Epoch 9/20, Loss: 0.7494, Train Accuracy: 0.6941
# Epoch 10/20, Loss: 0.6688, Train Accuracy: 0.7354
# Epoch 11/20, Loss: 0.5951, Train Accuracy: 0.7686
# Epoch 12/20, Loss: 0.5234, Train Accuracy: 0.8017
# Epoch 13/20, Loss: 0.4607, Train Accuracy: 0.8304
# Epoch 14/20, Loss: 0.4115, Train Accuracy: 0.8507
# Epoch 15/20, Loss: 0.3571, Train Accuracy: 0.8733
# Epoch 16/20, Loss: 0.3216, Train Accuracy: 0.8886
# Epoch 17/20, Loss: 0.3017, Train Accuracy: 0.8950
# Epoch 18/20, Loss: 0.2685, Train Accuracy: 0.9070
# Epoch 19/20, Loss: 0.2450, Train Accuracy: 0.9168
# Epoch 20/20, Loss: 0.2203, Train Accuracy: 0.9253
# Test Loss: 2.6925, Test Accuracy: 0.4993

# %% [markdown]
# # Torch Tokenizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model2.parameters(), lr=0.001)

num_epochs = 20
model2.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model2(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model2.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model2(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.4824, Train Accuracy: 0.3067
# Epoch 2/20, Loss: 1.2369, Train Accuracy: 0.4475
# Epoch 3/20, Loss: 1.0933, Train Accuracy: 0.5176
# Epoch 4/20, Loss: 0.9795, Train Accuracy: 0.5763
# Epoch 5/20, Loss: 0.8686, Train Accuracy: 0.6331
# Epoch 6/20, Loss: 0.7624, Train Accuracy: 0.6863
# Epoch 8/20, Loss: 0.5682, Train Accuracy: 0.7820
# Epoch 9/20, Loss: 0.4816, Train Accuracy: 0.8226
# Epoch 10/20, Loss: 0.4036, Train Accuracy: 0.8546
# Epoch 11/20, Loss: 0.3513, Train Accuracy: 0.8748
# Epoch 12/20, Loss: 0.3090, Train Accuracy: 0.8922
# Epoch 13/20, Loss: 0.2636, Train Accuracy: 0.9087
# Epoch 14/20, Loss: 0.2395, Train Accuracy: 0.9204
# Epoch 15/20, Loss: 0.2155, Train Accuracy: 0.9277
# Epoch 16/20, Loss: 0.2064, Train Accuracy: 0.9288
# Epoch 17/20, Loss: 0.1927, Train Accuracy: 0.9361
# Epoch 18/20, Loss: 0.1896, Train Accuracy: 0.9349
# Epoch 19/20, Loss: 0.1628, Train Accuracy: 0.9443
# Epoch 20/20, Loss: 0.1551, Train Accuracy: 0.9470
# Test Loss: 3.9185, Test Accuracy: 0.5014

# %%
import torch
import torch.nn as nn

class RNNModel3(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel3, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm1 = nn.LSTM(embed_size, lstm_units, batch_first=True)
        # self.dropout = nn.Dropout(0.25)
        self.lstm2 = nn.LSTM(lstm_units, lstm_units, batch_first=True)
        self.lstm3 = nn.LSTM(lstm_units, lstm_units, batch_first=True)
        # self.fc1 = nn.Linear(lstm_units, hidden_size)
        #self.relu = nn.ReLU()
        self.fc = nn.Linear(lstm_units, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm1(x)
        # x = self.dropout(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)

        x = torch.mean(x, dim=1)
        # x = self.fc1(x)
        # x = self.relu(x)
        x = self.fc(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model3 = RNNModel3(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model3.to(device)
# Out:
# RNNModel3(
#   (embedding): Embedding(112680, 200)
#   (lstm1): LSTM(200, 128, batch_first=True)
#   (lstm2): LSTM(128, 128, batch_first=True)
#   (lstm3): LSTM(128, 128, batch_first=True)
#   (fc): Linear(in_features=128, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model3.parameters(), lr=0.001)

num_epochs = 20
model3.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model3(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model3.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model3(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.5600, Train Accuracy: 0.2634
# Epoch 2/20, Loss: 1.5248, Train Accuracy: 0.2987
# Epoch 3/20, Loss: 1.5306, Train Accuracy: 0.3083
# Epoch 4/20, Loss: 1.4827, Train Accuracy: 0.3223
# Epoch 5/20, Loss: 1.4127, Train Accuracy: 0.3558
# Epoch 6/20, Loss: 1.3943, Train Accuracy: 0.3591
# Epoch 7/20, Loss: 1.3660, Train Accuracy: 0.3705
# Epoch 8/20, Loss: 1.2665, Train Accuracy: 0.4134
# Epoch 9/20, Loss: 1.1932, Train Accuracy: 0.4584
# Epoch 10/20, Loss: 1.1354, Train Accuracy: 0.4878
# Epoch 11/20, Loss: 1.0661, Train Accuracy: 0.5299
# Epoch 12/20, Loss: 1.0034, Train Accuracy: 0.5657
# Epoch 13/20, Loss: 0.9320, Train Accuracy: 0.6076
# Epoch 14/20, Loss: 0.8700, Train Accuracy: 0.6439
# Epoch 15/20, Loss: 0.8065, Train Accuracy: 0.6795
# Epoch 16/20, Loss: 0.7403, Train Accuracy: 0.7147
# Epoch 17/20, Loss: 0.6933, Train Accuracy: 0.7379
# Epoch 18/20, Loss: 0.6286, Train Accuracy: 0.7685
# Epoch 19/20, Loss: 0.5768, Train Accuracy: 0.7937
# Epoch 20/20, Loss: 0.5223, Train Accuracy: 0.8189
# Test Loss: 1.5940, Test Accuracy: 0.4713

# %% [markdown]
# # **GRU**

# %%
import torch
import torch.nn as nn

class RNNModel4(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel4, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.gru1 = nn.GRU(embed_size, lstm_units, batch_first=True)
        # self.dropout = nn.Dropout(0.25)
        self.gru2 = nn.GRU(lstm_units, lstm_units, batch_first=True)
        self.gru3 = nn.GRU(lstm_units, lstm_units, batch_first=True)
        self.fc1 = nn.Linear(lstm_units, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.gru1(x)
        # x = self.dropout(x)
        x, _ = self.gru2(x)
        x, _ = self.gru3(x)

        x = torch.mean(x, dim=1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model4 = RNNModel4(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model4.to(device)
# Out:
# RNNModel4(
#   (embedding): Embedding(112680, 200)
#   (gru1): GRU(200, 128, batch_first=True)
#   (gru2): GRU(128, 128, batch_first=True)
#   (gru3): GRU(128, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %% [markdown]
# # Imbalanced

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model4.parameters(), lr=0.001)

num_epochs = 20
model4.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model4(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model4.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model4(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 0.7047, Train Accuracy: 0.7348
# Epoch 2/20, Loss: 0.5778, Train Accuracy: 0.7770
# Epoch 3/20, Loss: 0.5103, Train Accuracy: 0.8027
# Epoch 4/20, Loss: 0.4432, Train Accuracy: 0.8314
# Epoch 5/20, Loss: 0.3785, Train Accuracy: 0.8583
# Epoch 6/20, Loss: 0.3243, Train Accuracy: 0.8805
# Epoch 7/20, Loss: 0.2834, Train Accuracy: 0.8975
# Epoch 8/20, Loss: 0.2524, Train Accuracy: 0.9086
# Epoch 9/20, Loss: 0.2292, Train Accuracy: 0.9175
# Epoch 10/20, Loss: 0.2124, Train Accuracy: 0.9235
# Epoch 11/20, Loss: 0.1980, Train Accuracy: 0.9290
# Epoch 12/20, Loss: 0.1868, Train Accuracy: 0.9327
# Epoch 13/20, Loss: 0.1784, Train Accuracy: 0.9354
# Epoch 14/20, Loss: 0.1695, Train Accuracy: 0.9390
# Epoch 15/20, Loss: 0.1642, Train Accuracy: 0.9413
# Epoch 16/20, Loss: 0.1580, Train Accuracy: 0.9426
# Epoch 17/20, Loss: 0.1528, Train Accuracy: 0.9449
# Epoch 18/20, Loss: 0.1494, Train Accuracy: 0.9457
# Epoch 19/20, Loss: 0.1472, Train Accuracy: 0.9466
# Epoch 20/20, Loss: 0.1435, Train Accuracy: 0.9479
# Test Loss: 1.1236, Test Accuracy: 0.7539

# %% [markdown]
# # Balanced

# %%
import torch
import torch.nn as nn

class RNNModel5(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel5, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.gru1 = nn.GRU(embed_size, lstm_units, batch_first=True)
        self.dropout = nn.Dropout(0.15)
        self.gru2 = nn.GRU(lstm_units, lstm_units, batch_first=True)
        self.gru3 = nn.GRU(lstm_units, lstm_units, batch_first=True)
        self.fc1 = nn.Linear(lstm_units, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.gru1(x)

        x, _ = self.gru2(x)
        x, _ = self.gru3(x)

        x = torch.mean(x, dim=1)
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model5 = RNNModel5(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model5.to("cuda")
# Out:
# RNNModel5(
#   (embedding): Embedding(112680, 200)
#   (gru1): GRU(200, 128, batch_first=True)
#   (dropout): Dropout(p=0.15, inplace=False)
#   (gru2): GRU(128, 128, batch_first=True)
#   (gru3): GRU(128, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model5.parameters(), lr=0.001)

num_epochs = 20
model5.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model5(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model5.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model5(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.4748, Train Accuracy: 0.3073
# Epoch 2/20, Loss: 1.1779, Train Accuracy: 0.4748
# Epoch 3/20, Loss: 1.0266, Train Accuracy: 0.5495
# Epoch 4/20, Loss: 0.9014, Train Accuracy: 0.6160
# Epoch 5/20, Loss: 0.7781, Train Accuracy: 0.6792
# Epoch 6/20, Loss: 0.6433, Train Accuracy: 0.7459
# Epoch 7/20, Loss: 0.5213, Train Accuracy: 0.8014
# Epoch 8/20, Loss: 0.4129, Train Accuracy: 0.8482
# Epoch 9/20, Loss: 0.3347, Train Accuracy: 0.8810
# Epoch 10/20, Loss: 0.2759, Train Accuracy: 0.9014
# Epoch 11/20, Loss: 0.2363, Train Accuracy: 0.9172
# Epoch 12/20, Loss: 0.2078, Train Accuracy: 0.9274
# Epoch 13/20, Loss: 0.1853, Train Accuracy: 0.9340
# Epoch 14/20, Loss: 0.1690, Train Accuracy: 0.9409
# Epoch 15/20, Loss: 0.1553, Train Accuracy: 0.9458
# Epoch 16/20, Loss: 0.1418, Train Accuracy: 0.9499
# Epoch 17/20, Loss: 0.1370, Train Accuracy: 0.9533
# Epoch 18/20, Loss: 0.1327, Train Accuracy: 0.9530
# Epoch 19/20, Loss: 0.1260, Train Accuracy: 0.9550
# Epoch 20/20, Loss: 0.1150, Train Accuracy: 0.9588
# Test Loss: 2.9019, Test Accuracy: 0.5125

# %% [markdown]
# # **RNN**

# %%
class RNNModel6(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel6, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn1 = nn.RNN(embed_size, lstm_units, batch_first=True)
        # self.dropout = nn.Dropout(0.1)
        self.rnn2 = nn.RNN(lstm_units, lstm_units, batch_first=True)
        self.rnn3 = nn.RNN(lstm_units, lstm_units, batch_first=True)
        self.fc1 = nn.Linear(lstm_units, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn1(x)
        x, _ = self.rnn2(x)
        x, _ = self.rnn3(x)

        x = torch.mean(x, dim=1)
        # x = self.dropout(x)
        x = self.fc1(x)
        # x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model6 = RNNModel6(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model6.to(device)
# Out:
# RNNModel6(
#   (embedding): Embedding(112680, 200)
#   (rnn1): RNN(200, 128, batch_first=True)
#   (rnn2): RNN(128, 128, batch_first=True)
#   (rnn3): RNN(128, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model6.parameters(), lr=0.001)

num_epochs = 20
model6.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model6.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 0.9358, Train Accuracy: 0.6975
# Epoch 2/20, Loss: 0.9210, Train Accuracy: 0.6980
# Epoch 3/20, Loss: 0.9260, Train Accuracy: 0.6992
# Epoch 4/20, Loss: 0.9003, Train Accuracy: 0.6990
# Epoch 5/20, Loss: 0.8866, Train Accuracy: 0.6989
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-3ece94f27e09> in <cell line: 6>()
#      14         # print(labels)
#      15         optimizer.zero_grad()
# ---> 16         outputs = model6(texts)
#      17         loss = criterion(outputs, labels)
#      18         loss.backward()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# <ipython-input-46-beefb9904100> in forward(self, x)
#      15     def forward(self, x):
#      16         x = self.embedding(x)
# ---> 17         x, _ = self.rnn1(x)
#      18         x, _ = self.rnn2(x)
#      19         x, _ = self.rnn3(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     584         if batch_sizes is None:
#     585             if self.mode == 'RNN_TANH':
# --> 586                 result = _VF.rnn_tanh(input, hx, self._flat_weights, self.bias, self.num_layers,
#     587                                       self.dropout, self.training, self.bidirectional,
#     588                                       self.batch_first)
#
# KeyboardInterrupt:

# %%
class RNNModel6(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel6, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn1 = nn.RNN(embed_size, lstm_units, batch_first=True)
        # self.dropout = nn.Dropout(0.1)
        self.rnn2 = nn.RNN(lstm_units, lstm_units, batch_first=True)
        self.rnn3 = nn.RNN(lstm_units, lstm_units, batch_first=True)
        self.fc1 = nn.Linear(lstm_units, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn1(x)
        x, _ = self.rnn2(x)
        x, _ = self.rnn3(x)

        x = torch.mean(x, dim=1)
        # x = self.dropout(x)
        x = self.fc1(x)
        # x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
lstm_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model6 = RNNModel6(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model6.to(device)
# Out:
# RNNModel6(
#   (embedding): Embedding(112680, 200)
#   (rnn1): RNN(200, 128, batch_first=True)
#   (rnn2): RNN(128, 128, batch_first=True)
#   (rnn3): RNN(128, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model6.parameters(), lr=0.002)

num_epochs = 20
model6.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model6.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 0.9493, Train Accuracy: 0.6975
# Epoch 2/20, Loss: 0.9167, Train Accuracy: 0.6995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-044f2e6976c0> in <cell line: 6>()
#      16         outputs = model6(texts)
#      17         loss = criterion(outputs, labels)
# ---> 18         loss.backward()
#      19         optimizer.step()
#      20         train_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     523                 inputs=inputs,
#     524             )
# --> 525         torch.autograd.backward(
#     526             self, gradient, retain_graph, create_graph, inputs=inputs
#     527         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     265     # some Python versions print out the first line of a multi-line function
#     266     # calls in the traceback and some print out the last line
# --> 267     _engine_run_backward(
#     268         tensors,
#     269         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     742         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743     try:
# --> 744         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745             t_outputs, *args, **kwargs
#     746         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
class RNNModel6(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel6, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn1 = nn.RNN(embed_size, rnn_units, batch_first=True)
        # self.dropout = nn.Dropout(0.1)
        self.rnn2 = nn.RNN(rnn_units, rnn_units,4, batch_first=True)
        self.fc1 = nn.Linear(rnn_units, hidden_size)
        # self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn1(x)
        x, _ = self.rnn2(x)
        # x, _ = self.rnn3(x)

        x = torch.mean(x, dim=1)
        # x = self.dropout(x)
        x = self.fc1(x)
        # x = self.relu(x)
        x = self.fc2(x)
        # x = self.softmax(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
rnn_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model6 = RNNModel6(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model6.to(device)
# Out:
# RNNModel6(
#   (embedding): Embedding(112680, 200)
#   (rnn1): RNN(200, 128, batch_first=True)
#   (rnn2): RNN(128, 128, num_layers=4, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model6.parameters(), lr=0.001)

num_epochs = 20
model6.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model6.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 0.9495, Train Accuracy: 0.6961
# Epoch 2/20, Loss: 0.9282, Train Accuracy: 0.6994
# Epoch 3/20, Loss: 0.8975, Train Accuracy: 0.6989
# Epoch 4/20, Loss: 0.8879, Train Accuracy: 0.6996
# Epoch 5/20, Loss: 0.8843, Train Accuracy: 0.6997
# Epoch 6/20, Loss: 0.8758, Train Accuracy: 0.6996
# Epoch 7/20, Loss: 0.8695, Train Accuracy: 0.6994
# Epoch 8/20, Loss: 0.8542, Train Accuracy: 0.6993
# Epoch 9/20, Loss: 0.8606, Train Accuracy: 0.6995
# Epoch 10/20, Loss: 0.8542, Train Accuracy: 0.6995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-3ece94f27e09> in <cell line: 6>()
#      16         outputs = model6(texts)
#      17         loss = criterion(outputs, labels)
# ---> 18         loss.backward()
#      19         optimizer.step()
#      20         train_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     523                 inputs=inputs,
#     524             )
# --> 525         torch.autograd.backward(
#     526             self, gradient, retain_graph, create_graph, inputs=inputs
#     527         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     265     # some Python versions print out the first line of a multi-line function
#     266     # calls in the traceback and some print out the last line
# --> 267     _engine_run_backward(
#     268         tensors,
#     269         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     742         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743     try:
# --> 744         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745             t_outputs, *args, **kwargs
#     746         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
class RNNModel6(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel6, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn1 = nn.RNN(embed_size, rnn_units, batch_first=True)
        self.rnn2 = nn.RNN(rnn_units, rnn_units,2, batch_first=True)
        self.fc2 = nn.Linear(rnn_units, output_size)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn1(x)
        x, _ = self.rnn2(x)
        x = torch.mean(x, dim=1)
        x = self.fc2(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
rnn_units = 128
hidden_size = 64
output_size = 5
maxlen = 100

model6 = RNNModel6(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model6.to(device)
# Out:
# RNNModel6(
#   (embedding): Embedding(30522, 200)
#   (rnn1): RNN(200, 128, batch_first=True)
#   (rnn2): RNN(128, 128, num_layers=2, batch_first=True)
#   (fc2): Linear(in_features=128, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model6.parameters(), lr=0.0007)

num_epochs = 10
model6.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model6.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/10, Loss: 0.9398, Train Accuracy: 0.6970
# Epoch 2/10, Loss: 0.9271, Train Accuracy: 0.6961
# Epoch 3/10, Loss: 0.9057, Train Accuracy: 0.6976
# Epoch 4/10, Loss: 0.8908, Train Accuracy: 0.6988
# Epoch 5/10, Loss: 0.8770, Train Accuracy: 0.6994
# Epoch 6/10, Loss: 0.8353, Train Accuracy: 0.7032
# Epoch 7/10, Loss: 0.8215, Train Accuracy: 0.7039
# Epoch 8/10, Loss: 0.8005, Train Accuracy: 0.7076
# Epoch 9/10, Loss: 0.7895, Train Accuracy: 0.7113
# Epoch 10/10, Loss: 0.7949, Train Accuracy: 0.7106
# Test Loss: 0.8130, Test Accuracy: 0.7058

# %% [markdown]
# # **RNN Balanced**

# %% [markdown]
# # RNN Balanced BERT tokenizer One FC layer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model6.parameters(), lr=0.005)

num_epochs = 20
model6.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model6.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.6053, Train Accuracy: 0.2224
# Epoch 2/20, Loss: 1.5991, Train Accuracy: 0.2279
# Epoch 3/20, Loss: 1.5818, Train Accuracy: 0.2410
# Epoch 4/20, Loss: 1.5649, Train Accuracy: 0.2488
# Epoch 5/20, Loss: 1.5489, Train Accuracy: 0.2758
# Epoch 6/20, Loss: 1.5108, Train Accuracy: 0.2982
# Epoch 7/20, Loss: 1.5178, Train Accuracy: 0.3103
# Epoch 8/20, Loss: 1.5083, Train Accuracy: 0.2941
# Epoch 9/20, Loss: 1.5029, Train Accuracy: 0.2991
# Epoch 10/20, Loss: 1.4908, Train Accuracy: 0.3189
# Epoch 11/20, Loss: 1.4642, Train Accuracy: 0.3405
# Epoch 12/20, Loss: 1.4454, Train Accuracy: 0.3330
# Epoch 13/20, Loss: 1.4416, Train Accuracy: 0.3366
# Epoch 14/20, Loss: 1.4408, Train Accuracy: 0.3338
# Epoch 15/20, Loss: 1.5277, Train Accuracy: 0.2991
# Epoch 16/20, Loss: 1.4326, Train Accuracy: 0.3368
# Epoch 17/20, Loss: 1.5101, Train Accuracy: 0.3160
# Epoch 18/20, Loss: 1.4660, Train Accuracy: 0.3400
# Epoch 19/20, Loss: 1.3987, Train Accuracy: 0.3732
# Epoch 20/20, Loss: 1.3110, Train Accuracy: 0.3984
# Test Loss: 1.3895, Test Accuracy: 0.3575

# %% [markdown]
# # RNN 2FC layers

# %%
class RNNModel6(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(RNNModel6, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn1 = nn.RNN(embed_size, rnn_units, batch_first=True)
        self.rnn2 = nn.RNN(rnn_units, rnn_units,2, batch_first=True)
        self.fc1 = nn.Linear(rnn_units, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn1(x)
        x, _ = self.rnn2(x)
        x = torch.mean(x, dim=1)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# Model parameters
vocab_size = len(vocab)
embed_size = 200
rnn_units = 256
hidden_size = 64
output_size = 5
maxlen = 100

model6 = RNNModel6(vocab_size, embed_size, hidden_size, output_size)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model6.to(device)
# Out:
# RNNModel6(
#   (embedding): Embedding(30522, 200)
#   (rnn1): RNN(200, 256, batch_first=True)
#   (rnn2): RNN(256, 256, num_layers=2, batch_first=True)
#   (fc1): Linear(in_features=256, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )

# %% [markdown]
# # RNN Balanced Torch tokenizer Two FC layer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model6.parameters(), lr=0.0003)

num_epochs = 20
model6.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model6.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model6(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 1.6093, Train Accuracy: 0.2066
# Epoch 2/20, Loss: 1.6049, Train Accuracy: 0.2230
# Epoch 3/20, Loss: 1.6014, Train Accuracy: 0.2314
# Epoch 4/20, Loss: 1.5893, Train Accuracy: 0.2447
# Epoch 5/20, Loss: 1.5313, Train Accuracy: 0.2926
# Epoch 6/20, Loss: 1.4635, Train Accuracy: 0.3287
# Epoch 7/20, Loss: 1.4170, Train Accuracy: 0.3546
# Epoch 8/20, Loss: 1.4611, Train Accuracy: 0.3470
# Epoch 9/20, Loss: 1.7289, Train Accuracy: 0.3164
# Epoch 10/20, Loss: 1.5812, Train Accuracy: 0.2586
# Epoch 11/20, Loss: 1.5560, Train Accuracy: 0.3168
# Epoch 12/20, Loss: 1.4113, Train Accuracy: 0.3628
# Epoch 13/20, Loss: 1.4085, Train Accuracy: 0.3604
# Epoch 14/20, Loss: 1.3429, Train Accuracy: 0.3930
# Epoch 15/20, Loss: 1.3145, Train Accuracy: 0.4101
# Epoch 16/20, Loss: 1.2874, Train Accuracy: 0.4231
# Epoch 17/20, Loss: 1.2640, Train Accuracy: 0.4399
# Epoch 18/20, Loss: 1.2194, Train Accuracy: 0.4517
# Epoch 19/20, Loss: 1.1911, Train Accuracy: 0.4722
# Epoch 20/20, Loss: 1.1564, Train Accuracy: 0.4901
# Test Loss: 1.4016, Test Accuracy: 0.4350

# %% [markdown]
# # **Second Part**

# %% [markdown]
# # Transfer label =2,4 to Test set

# %%
filtered_data = [entry for entry in data if 'reviewText' in entry and entry['overall'] not in [2, 4]]
separated_data = [entry for entry in data if 'reviewText' in entry and entry['overall'] in [2, 4]]

# Extract labels and encoded texts for filtered data
filtered_labels = [entry['overall'] for entry in filtered_data if 'reviewText' in entry]
filtered_texts = [text_pipeline(entry['reviewText']) for entry in filtered_data if 'reviewText' in entry]

# Extract labels and encoded texts for separated data
separated_labels = [entry['overall'] for entry in separated_data if 'reviewText' in entry]
separated_texts = [text_pipeline(entry['reviewText']) for entry in separated_data if 'reviewText' in entry]

# %%
filtered_dataset = ReviewsDataset(filtered_texts, filtered_labels)
filtered_train_size = int(0.8 * len(filtered_dataset))
filtered_test_size = len(filtered_dataset) - filtered_train_size
filtered_train, filtered_test = random_split(filtered_dataset, [filtered_train_size, filtered_test_size])
separated_dataset = ReviewsDataset(separated_texts, separated_labels)
filtered_train_dataloader = DataLoader(filtered_train, batch_size=64, shuffle=True, collate_fn=collate_fn)
filtered_test_dataloader = DataLoader(filtered_test, batch_size=64, shuffle=True, collate_fn=collate_fn)
separated_dataloader = DataLoader(separated_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# # Filtered & Unbalanced

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model4.parameters(), lr=0.001)

num_epochs = 10
model4.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in filtered_train_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model4(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(filtered_train_dataloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model4.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in filtered_test_dataloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model4(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(filtered_test_dataloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/10, Loss: 0.2879, Train Accuracy: 0.8986
# Epoch 2/10, Loss: 0.1814, Train Accuracy: 0.9345
# Epoch 3/10, Loss: 0.1353, Train Accuracy: 0.9531
# Epoch 4/10, Loss: 0.0989, Train Accuracy: 0.9671
# Epoch 5/10, Loss: 0.0739, Train Accuracy: 0.9765
# Epoch 6/10, Loss: 0.0578, Train Accuracy: 0.9820
# Epoch 7/10, Loss: 0.0480, Train Accuracy: 0.9851
# Epoch 8/10, Loss: 0.0422, Train Accuracy: 0.9869
# Epoch 9/10, Loss: 0.0376, Train Accuracy: 0.9882
# Epoch 10/10, Loss: 0.0340, Train Accuracy: 0.9896
# Test Loss: 0.3247, Test Accuracy: 0.9318

# %%
def select_random_samples(dataloader, num_samples):
    all_samples = []
    for batch in dataloader:
        inputs, labels = batch
        for input, label in zip(inputs, labels):
            all_samples.append((input, label))

    random_samples = random.sample(all_samples, num_samples)
    inputs, labels = zip(*random_samples)
    return inputs, labels

random_inputs, random_labels = select_random_samples(separated_dataloader, 200)

# Step 3: Prepare the inputs for the model
inputs_tensor = pad_sequence(random_inputs, batch_first=True)
labels_tensor = torch.tensor(random_labels)

# Step 4: Pass the inputs through the model
model4.eval()
with torch.no_grad():
    inputs_tensor = inputs_tensor.to(device)
    outputs = model4(inputs_tensor)

# Step 5: Evaluate the model's performance
predicted_labels = torch.argmax(outputs, dim=1)
def decode_text(numerical_text):
    return ' '.join([vocab.lookup_token(token) for token in numerical_text if token != vocab['<unk>']])

# Print the results for each sample
for i in range(len(random_inputs)):
    decoded_input = decode_text(random_inputs[i])
    print(f"Sample {i+1}:")
    print(f"Text: {decoded_input}")
    print(f"Expected output (Actual label): {labels_tensor[i]}")
    print(f"Current output (Predicted label): {predicted_labels[i]+1}")
    print("-" * 30)
# Out:
# Sample 1:
# Text: good shoulder rest
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 2:
# Text: fun pedal . little bit fiddly because the pedal is pretty ambitious for the size of the knobs .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 3:
# Text: well , its chinese made which quality wise raises a red flag with me ( no pun intended ) . besides that it makes a good starter harmonica for someone who wants to learn how to play one .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 4:
# Text: smooth playability . i strung a second guitar and they did not last very long sitting idle on a stand . picked it up about 3 months later and they seemed harsh . if these are going on your main axe and you will be restringing at least once a month . go for it !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 5:
# Text: they sound great ! hum is to a minimum .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 6:
# Text: fair
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 7:
# Text: clips work well with long stems . a little shaky with the short ones with thick felts
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 8:
# Text: this is a great mic for the price . i usually record instrumentals and use a cheap dynamic mic . this marantz cardiod is much better . i would not be able to tell from the results that this is a relatively inexpensive cardiod mic . the stand is a really nice feature as is the excellent carrying case . if you are looking to upgrade your home recording this is a good choice .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 9:
# Text: trying to find the perfect slide isn ' t easy . everybody ' s got different size fingers and preferences . i suppose i can go to a store and ask them if i can stick my finger in all of their slides . . . anyway , this slide is ok for me . it fits my ring finger fine , but i guess i prefer something skinnier . i ' m not a slide player . i just have to cover a few slide licks . for that , i won ' t complain about the size . build quality seems nice . i ' ve dropped it twice , but no break .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 10:
# Text: i ' ve been using ableton for 4 years and it never crashes . i connected this interface with live 9 on windows 8 . 1 i set my default playback and recording device as line out scarlett 2i2 usb and set it as my default device . it crashes every time in ableton but works well with listening to music either on my computer or on youtube . sometimes i hears pops and clicks after 5 minutes and have to reset the asio4all driver which is the same issue with my audio technica at2020 usb mic . my computer is an amd system and i have used my at2020 ( usb ) on a dell intel laptop but i never heard any pops and clicks even after using for hours so i am not sure whether this has to do with different hardware used in different computers or whatsoever but . i think it would be better to use this interface on and intel based system because through my experience .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 11:
# Text: i ' ve played harmonica for over 50 years . i started playing golden melodies in the early 1990 ' s . it ' s still my favorite harmonica . i ' ve had several sydel 1847 , suzuki manji , suzuki fabulous , lee oscar , hohner marine band , etc . i keep coming back to the golden melody . they ' re kind of a pain , if you drop one you ' ll likely have to reset the covers . if the cover gets knocked a little , the screw will be loose and fall out . but , i put up with it because i just like the feel of it , with the curved shape . they ' re a little stiff to bend , but they can be made to overblow nicely . some people won ' t like them because they ' re tuned to equal temperment , of course you can retune them . i don ' t really recommend these for beginners , because they ' re stiff to bend , but for advanced players , you should try one .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 12:
# Text: this is great cleaner to keep your guitar in great shape , it even smells great
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 13:
# Text: the mobilepre has been around for a while now - note that the photo shown here is outdated , the unit is now black and grey rather than blue/white . while this unit may not be the absolute latest and greatest audio interface on the market it has pretty solid support and history . i got mine about 8 months ago for ~$60 ( i think there might have been a pricing mistake ! ) . works well with windows 7 32 and 64 bit os . my only minor gripe is that the minimum number of samples is 128 , which makes for roughly a 7 ms total latency . the built-in soundcard on my hp laptop works down to 64 samples ( 32 using jack in linux ) , but cannot touch the sound of the mobilepre . note - using reaper permits using a wdm kernel streaming driver instead of asio , which allows a little better latency . still , sound travels roughly 1 foot each millisecond , so the total latency is like have an amp about 7 feet away , which is barely noticable . solidly built , great for guitar . the preamp section when using a dynamic mic is a bit noisy though . would recommend to a friend .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 14:
# Text: this item contains 2 sticks in a pack . they work good but are a little bulky at the handle . each one has two rubber bands that rolls down to tighten the strands for a louder sound or loose for a brush sound . i like them .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 15:
# Text: heavy and kind of crappy . it does the job though .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 16:
# Text: great strings , deep rich tones from both highs and lows , a very good value for the dollar and customer service is second to none
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 17:
# Text: working well
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 18:
# Text: unfortunately , the latency of this product is terrible . you get what you pay for . i wouldn ' t recommend this to people using yamaha instruments , especially . i have a yamaha ypt-310 keyboard , and the latency was terrible . it was at least two beats behind . hearing my laptop echo my keyboard while recording wasn ' t ideal . now , i have the midi cord meant for yamaha instruments , and it ' s works much better barely any noticeable latency . for those who are looking at this trying to decide what cord , if you have a yamaha , i suggest the yamaha ux16 usb midi interface . i can ' t comment on how this cord works on other instruments because i haven ' t tested it on any others . however , i don ' t recommend it for yamaha users . and quite frankly , i ' d recommend that any other user just look around . find a higher priced cord , it will probably work better in the end .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 19:
# Text: decent stamp for writing out chords . i was hoping it would be slightly smaller , actually , so i could designate chords on sheet music that doesn ' t have each chord shown . it ' s a little too big for that purpose , at least on the sheet music that i have tried it on , so far . the stamp is sturdy and well made in america , and though the stamp is slightly askew on the block , it is very usable and useful . i would definitely buy from this company again .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 20:
# Text: i ' m a solo singer-songwriter . i ' m using this to support my solo outings on bass , or on guitar or on keyboards with vocals . i essentially needed a flexible looper and mixer with mostly foot operation especially when i ' m playing guitar or bass . this unit gives me both . i ' m happy with the number of tracks , the intuitive way the footswitch is laid out and the ease of using this thing live . my problem is that the looper will not play my self-designed loops that i try adding to the sd card . i label the 4 tracks and the drum track in exactly same way the loops that come with the unit are labeled . i include the necessary text file info . i ' ve made sure they ' re stereo wavs of the exact same length etc . . . and i can only get the footswitch to display the numbers i ' ve given the loops , but the unit won ' t play them . i checked the user forums on their website and others have reported this same issue , but there seems to be different fixes depending on some key details . that ' s why it ' s important to be able to interface with eh support so that they can isolate my specific process for creating and loading my own loops . i ' ve written to support a few times to guide me with my specific problem and have heard nothing . i ' m disappointed with the level of support from eh . this unit + footswitch were too expensive to not be able to get it to do100% of what i need it do ( and that its instructions say it was also designed to do ) . i ' m hoping boss tailors the next iteration of its rc-505 to musicians needing more hands-free operation . if they do , i ' m dumping this eh looper and getting the boss . the only reason i didn ' t get the foot-operated rc-300 is because i really do need 4-5 independent , volume controllable tracks and it really only offers 3 . the lack of eh support really ruined this for me . other minuses the lack of a true , quick undo functionality . that ' s something $150 loopers have . the headphone out/monitor signal isn ' t very loud even on the max setting . i end up having to send it to a small headphone amp in order to truly monitor myself when i ' m in open mic situations and have to plug into the pa system . cumbersome !
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 21:
# Text: comfy strap . down one star due to plastic buckle touching banjo . no scratches yet just bugs me . 6 months usage at this point .
# Expected output (Actual label): 4
# Current output (Predicted label): 1
# ------------------------------
# Sample 22:
# Text: first of all , don ' t even try playing electric guitar without a compressor pedal . secondly , don ' t spend too much on a good compressor pedal ! buy this guy it ' ll do what you want and do it well and do it cheap all without taking up too much space on your board . buy now . the only reason i didn ' t go 5 stars is because it ' s not quite as good as the $200 stuff out there . . . but really ? $200 for a slightly better compression that won ' t even translate live unless you have a kick-a sound guy and sound system ? again , buy now .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 23:
# Text: this is my second one of these . k&m is always a good choice for sturdy gear . and these bars are heavy duty . however , the thumbscrews always stick and are a real bear to unstick without a tool . not a big deal in the studio , but really annoying on stage . not sure if it ' s the paint or the tolerance on the slots . i need to modify these to fix that ! 2 stars only because k&m should have fixed this before putting them out for distribution ! !
# Expected output (Actual label): 2
# Current output (Predicted label): 5
# ------------------------------
# Sample 24:
# Text: easy hookup
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 25:
# Text: put some aqulia strings on here and it ' s a pretty great travel uke . you won ' t be heartbroken if it ' s destroyed .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 26:
# Text: so i used this in 14 video interviews back to back 2 days . the sound is great and its easy to use .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 27:
# Text: it ' s a great mike , but it doesn ' t pick up sound . i think it ' s designed for life music recording . i tried to record a violin and guitar and the sound quality was surprising . but for screencasting it ' s barely there . i used screen-cast-o-matic , which has it ' s own equalizer and it brought the sound up very nicely , but i got lucky . for musicians recording a session - can ' t be better . and it looks very imposing . it comes with a very bad stand . i mean very bad . i never thought it ' s possible to make it so poorly . get your own stand . the problem with the stand is that the cord that comes with the mike is thick and tends to turn the mike over , loosening the connection and making the whole thing unstable . i ' d get those stands with clamps , if possible .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 28:
# Text: good quality , just a little slicker than i expected . it can slide on your shoulder a little more than desired .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 29:
# Text: makes quick work of loosening strings . got a kinda cheap guitar and needed to sand down the bridge thingy , so i needed to loosen the strings to get to it .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 30:
# Text: i paired this up with two speakers , both at 300w rms at 8ohms and this powers them up . however it only puts out 180 at 8ohms so i have plenty of headroom on the speakers . the mixer works pretty well and it doesn ' t pick up any feedback even without fqb . powers a garaged band practice well and i hope to put on small park concerts with this and a few more speakers !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 31:
# Text: decent scissor boom arm . somewhat short in its length , so your mic set up should be pretty close to where you are sitting . also , this scissor boom arm will hold any average weight mic ( like a behringer ultravoice ) , but i don ' t think it would hold any mic that has any weight to it ( like a shure 55 or rode procaster ) . this scissor boom arm will in no way hold a blue yeti , no matter what others will tell you . it may hold it firmly for a little while , but eventually it will fail to hold up to the weight . this is a great scissor boom arm for someone starting out or doesn ' t want to invest in a heil or rode scissor boom arm . just make sure your mic doesn ' t weight too much .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 32:
# Text: this is a well manufactured product , i can see it withstanding a lot of abuse ( minus the power adapter which is of pretty average quality ) . the tone is great , very little coloration of the initial sound with an incredibly responsive eq and a decent notch filter . i bought this thinking i wouldn ' t use the sonic maximizer but it works great to even out the sound when strumming . its a little hard to describe what exactly it does , other than just brightening up the sound ( think taylor style tone ) thus far ive used a martin ooo-28ec ( passive k&k pure mini ) and an 000c-16gte ( fishman prefix , active with preamp ) with it and had great results . my one complaint about it comes with using it with a low output passive pickup . cranking the volume past halfway starts to throw out a nasty 60hz hum , luckily it has sufficient gain to compensate , which with a low ouput pickup won ' t really distort the sound much , and you can minimize the hum , though its still definitely there . ( note this is out of the 1/4 output i haven ' t tried the xlr yet , though i doubt it would be much different )
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 33:
# Text: product of canada . they are not gold-tone like some might think by looking at the picture . they do not have sabian on them . they are plain , silver-tone . if that is what you are looking for , the price is right !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 34:
# Text: great tool for practice , but if you want one to play live with , get the trio plus .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 35:
# Text: i don ' t feel like i ' ve found the perfect tuner yet but here ' s the pros and cons for this one . pros 1 . it ' s tiny , small enough you probably won ' t have to remove it when you put the uke away 2 . it ' s especially not that visible from the front 3 . it appears to be more robust than the snark style where the clip breaks off after a while cons 1 . i find the display to be harder to read , both in terms of size and design , it ' s definitely not intuitive what to do compared to a snark type . it ' s useable but expect to stare at it a bit and experiment and see if it gets better or worse . 2 . looking at the directions and comments it ' s clearly not intended to be left on .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 36:
# Text: worked great !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 37:
# Text: i ' ve got a love/hate relationship with these cables , in that they work really nicely , but they have a tendency to malfunction if they get moved around at all . i wired them into my gigrig on a pt pro , but have had them not work at the worst moment during a gig . i ' ve just got into the habit of checking all the cables before each show , but that seems like something you shouldn ' t have to worry about all the time . they are great , in that you can custom make your lengths so your pedal board looks sharp . and sonically , they do a great job too !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 38:
# Text: just have to retighten em once in awhile .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 39:
# Text: the medium weight gives you some sturdiness for pit orchestra work without adding too much extra weight to your trap case . stows fine as the arm can be folded into the top third so things don ' t get too messy in your trap case . although i don ' t like everything about yamaha , their medium weight hardware is fine and decently priced .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 40:
# Text: they seem cheaply made but i give them four ( 4 ) stars because i feel that they will work fine for me and i can only be hopeful that they will last hopefully more than a few months of rolling around in my tool box .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 41:
# Text: got it on time , it does put order to my effects , is priced well , no padded case no problem , plenty velcro came with it . no complaints , just think donner should sell 4 extension for the side for future pedals although i put seven on it with a large wah pedal no problem .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 42:
# Text: this item is just as it was described . well made , good detail , well worth your money folks . sw
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 43:
# Text: i would buy this harmanica for a child . it has a nice tone and it came in tune right out the box .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 44:
# Text: when i want to learn a song on my bass , i download the song onto my ipad , plug in using the jam , launch anytune plus , and that ' s all i need . works perfectly ! the only reason i didn ' t give it a 5 out of 6 is because i had to by a separate adapter for my new ipad retina ( was using ipad 2 ) and they charged me $35 for a 59 cent cable . that kind of thing really angers me . apple is the worst for that kind of stuff .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 45:
# Text: rode is a great company with awesome products . the nt2a sounds rich and full-bodied with nice features but beware it ' s heavy . i upgraded to this from the audio technica at2020 and was very happy the first time i started singing i got chills from how good i sounded . then i upgraded to the avantone pro cv12 . then i upgraded to the shure sm7b and now i ' m about to get a neumann tlm102 . all amazing microphones and the best in their price ranges in my opinion . now i have a pretty decent mic collection , along with a few others ( sm57 , sm58 , at2021 ) . you ' ll be set once you have options because the room , the gear , the song and how your voice or instrument playing sounds that day all play a part in picking the right mic for the job . rock on you guys ! p . s . never record without a mic preamp ! ! ! ( i have the golden age pre73 mkiii )
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 46:
# Text: i ' ve always had great luck with cbi cables and love the company . unfortunately out of three ordered , only two of them worked . will need to return the other for exchange if they ' ll take it without the cardboard sleeve .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 47:
# Text: the range is great , the metal chassis with rubber sections ( on both ) is great , the user-friendly operation makes the manual unnecessary , dual antennas strengthens the signal , and the input voltage is 100-240v . only downside is that the input jack on the transmitter was originally made of plastic ( why they would do that , and yet make the rest of it metal , i have no clue ) . so , i called line 6 and they sent me a metal jack for free . i was surprised at the good customer service from a company that markets to the masses .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 48:
# Text: the actual unit , ( not the shipping box . . . it was fine ) , arrived with the metal box scuffed up and heavily taped shut with a very sticky - gooey tape . people buy these things for the look of them . . . get it together on your quality control and presentation !
# Expected output (Actual label): 2
# Current output (Predicted label): 5
# ------------------------------
# Sample 49:
# Text: nice amp would recommend the marshall pedl-90008 mg pedal for this amp
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample

# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 58:
# Text: i have a fairly long torso ( i ' m 6 ' 1 . 75 and wear the same length pants as my 5 ' 10 ' tall brother ) and i found that this cushion did not support my guitar enough to reach the desired angle ( headstock to my eye level ) . sitting on a 19 chair , i have to use it in combination with a footrest , which kind of defeats its purpose . i imagine this is probably not the case with most guitarists . it arrived in good shape and seems to be well made .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 59:
# Text: they work . . a bit thin for the top posts for my plans for them but they work .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 60:
# Text: first-class construction , nice sound . sustain is a little disappointing . these need either a different alloy or different heat treatment .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 61:
# Text: seems to work alright . there ' s a small amount of lag ( don ' t know if that ' s the keyboard ' s fault or the computer ' s ) , making it almost impossible to play fast . key velocity sensitivity is actually annoying . you have to press hard every time , or you ' ll get almost nothing . and it ' s difficult to get anything in between . but it ' ll work for my purposes , and i can ' t really complain for the price .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 62:
# Text: i ended up ordering this cable to connect a 535q wah into a dyna comp on my pedaltrain 2 board . it ' s the perfect length , as the 1/2 foot cable was just a little bit too short . since then , i ' ve ordered these patch cable in other lengths , and they ' ve done a great job of cleaning up the look of my pedalboard .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 63:
# Text: is and does exactly as expected . came quickly , too ! .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 64:
# Text: this is just ok for a tuner . i ' ve tested about 8 different vibration tuners and this one comes out close to the bottom . the biggest thing i don ' t like about it is the swivel . i like to put my tuner down close to the nut ( instead of at the top of the headstock ) , but i can ' t with this one because the swivel is limited 360 and the screen does not have its own pivot . also , the battery compartment is a bit on the flimsy side . i gave it 2 stars for the display brightness and the accuracy seems pretty good . if you want a great tuner that ' s very flexible when it comes to screen postion , check out the intellitouch pt10 mini . i haven ' t found a better tuner yet .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 65:
# Text: it does what it is supposed to do , but , as other reviewers have mentioned , it ' s a shame there isn ' t a pocket for the power cord .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 66:
# Text: turns 90 great .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 67:
# Text: good flexibility , nice low end , thick overdrive . . .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 68:
# Text: this little beauty did indeed keep the strap locked on , and did the job well .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 69:
# Text: i bought this to replace the original speaker in a princeton reverb reissue . i really wanted more headroom but the same overall sound so after a bunch of research i decided on this speaker . it didn ' t sound bad , just didn ' t live up to what i had hoped for . there was a bit more headroom but it still broke up and it was more thick sounding than the original speaker - just didn ' t have that sparkle . . . .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 70:
# Text: not a pro stand at all . might be ok for home use but for a gig . . forget it . not sturdy , tips over and too light .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 71:
# Text: great color selection , but be ready for the color to wash out when you rinse them to get the ' spit ' out of them . some colors fade after time , some keep their color .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 72:
# Text: for the price you can ' t go wrong . . will order a more again .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 73:
# Text: i really wanted this to be a good product . it wasn ' t . the quality was sub par . not even a month old and it buzzes and snaps ( not my playing ) ) its due to weak electrical connections at -both- jack ends . not one . both . while an easy fix for anyone with some shrink tube and a soldering iron , i don ' t want to work to get new things working correctly . 2 stars .
# Expected output (Actual label): 2
# Current output (Predicted label): 5
# ------------------------------
# Sample 74:
# Text: it ' s fairly sturdy , just costs way too much for what it is . but they ' re the only game in town . . .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 75:
# Text: fast service . . . great product
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 76:
# Text: i bought two . i could use two more
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 77:
# Text: bought one of these instead of the gt-6 . it didn ' t work properly . recieved a second one it also didn ' t work . i will stick with the gt-6 .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample

# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 96:
# Text: this folder is very nice , but the pockets could be bigger to accommodate larger sheet music . the pockets are not the full size of the folder .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 97:
# Text: these cables work fine and the price is right . if you are a cable freak maybe they won ' t be good enough but i have been performing professional for over 30 years and i can ' t tell the difference between these and the super expensive guitar cables .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 98:
# Text: had to return it back . . . . headphone volume wasn ' t that clear to me . . .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 99:
# Text: i used it last night for a gig . made setting up my pedalboard faster and easier . will surely keep using it .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 100:
# Text: rock ' n roll electric guitar strings . if you ' ve got an electric guitar and know you need strings and nothing else , these will fit the bill .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 101:
# Text: good strings .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 102:
# Text: after i read the mixed reviews , i wasn ' t certain this strap would be a good investment . it is not cheap but it does work well . it is easy to take on and off , and it holds my classical guitar very well . i have no complaints and would recommend it . didn ' t give it five stars because its function is not all that demanding . how wonderful can a guitar strap be ? that said , this one is well made and works well . i think it was worth the price .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 103:
# ...
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 161:
# Text: not bad for the price . . . cant complain . . . not top of the line but well worth the price
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 162:
# Text: it works . perfect for swells when playing low-key songs . also good for upbeat songs to increase volume at the faster/heavier parts
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 163:
# Text: these are 12 bells , 6 pairs of 2 . they appear to be solid brass . the pairs are not identical - same casting , but hand etched with slight variations . the outside is polished , not quite to a mirror surface , but very pretty . the inside is unpolished and nothing special the clapper is a rough ring of metal . the six different shapes are as shown , and visually appealing . for people who care - i had reason to - the larger ones weigh about 45g . they are overall very decorative and would look good on a christmas tree . it ' s 4 stars instead of five because one of the smaller ones doesn ' t have much of a ring - it damps down immediately . only one of the 12 had a really gorgeous sustained sound . of course , these are small bells and you can ' t expect the world . one thing to be very aware of - the pairs aren ' t matched in tone . all 12 of mine have a different pitch , though some of the pairs are pretty close ( for musical purposes , that ' s bad . ) the largest pair were about a full step apart in tone . two from different pairs were a 5th apart . but that was likely coincidence these are nothing like precision musical instruments . the ones with the legs had a pronounced and unusual overtone , the others had typical bell overtones , with a 5th predominating . being small they aren ' t especially loud . i plan to use 2 of mine for a faux-victorian era/steampunk coffeemaker . i ' m tired of things that beep and want some ringing instead .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 164:
# Text: this pedal have been a good addition to my pedal board . it did take some time to dial in the right mix and level . i personally do not use the chorus and vibrato , but it does add a cool later to the sound . the delay is very good and natural sounding . this pedal is a great alternative to similar pedals that are much more expensive . the pedal is in a solid metal housing . the knobs are sturdy and have a good feel . overall a great pedal for the price . if you found this review helpful , please click helpful below .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 165:
# Text: good sound and less tinny than other round-wounds .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 166:
# Text: very happy with these . the price is right and sound good . on the brighter side . i am using the a and d string currently , have not tried the g and c strings yet .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 167:
# Text: this pedal works quite well and is able to pull off some of the excellent tone shaping that it ' s more expensive big brother does . the only reason i haven ' t given it 5 stars is that the output is a bit more quiet than i ' d expect , having to bring the volume up to max with the gain around 12 ' o ' clock to get it to match the volume that was present with the pedal disengaged . i ' d recommend it to anyone who wants something like the tech21 sansamp that doesn ' t quite have the scratch or is wanting to see what one could do for their sound without ponying up the cash right away .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 168:
# Text: the price was fair . works fine and arrived on time . i ' m happy with it . this is extra text to meet the stupid minimum requirements from amazon .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 169:
# Text: clips on my mic stand so i can see my guitar neck in low light situations .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 170:
# Text: very good item i like it
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample

# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 186:
# Text: nice , high quality jack . i wish the shaft was actually a little longer . i made my pedal board from 1/2 inch mdf so the shaft still did not fit through that thickness . i had to dremel out a cavity on the inside of the board so the jack would recess deep enough for the jack to stick out the other side . no connectivity issues - plugs fit snug and stay that way .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 187:
# Text: so , to my ears , these are just ok sounding on my lanikai curly koa baritone uke . i guess i was hoping for louder/brighter . these are warmer , quieter strings in this application . i gave 4 stars because the quality is definitely there , but i should try a different set for this particular uke . maybe these would be great on a mahogany uke ? totally subjective . . .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 188:
# Text: didn ' t sound good on my om guitar . strings are very subjective . . . these weren ' t for me . went back to d ' addario lights again .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 189:
# Text: it is a good case for the money and the materials it is made from . loose fit on a martin or martin dreadnought copy . but i prefer and abs case for my prize guitars and will pay the extra for them . if you have a slightly large dreadnought these should be a fine fit . they provide adequate protection for most factory level guitars but if you have over a $1000 in your guitar i would look to an abs better case .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 190:
# Text: nice and comfortable for those long gigs !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 191:
# Text: great '
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 192:
# Text: works great and fits in my gig bag front pouch
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 193:
# Text: i bought this amp a little less than a year ago . i have to say , it is a very good amp . good selection of amplifier models , good selection of effects , nice to have multiple channels ( lead , crunch , clean ) . it ' s also nice to have a single amp for guitar , bass or acoustic . the tones that this amp generates are outstanding . i would normally rate this as 5 stars , but it only gets 2 stars as peavey support for this amp is non-existent . i would not have purchased this had i known . the firmware has not been updated since 2013 . the edit program , from which you can manipulate the amp and save and load patches is the same version 1 . 0 that was released in 2013 , and is primitive at best . on top of that , i sent multiple queries to peavey customer support regarding this , and have never even received a courtesy reply . supporting your product is just as important , if not more so , than the product itself . updated firmware , updated and modern editing software , etc . can make a product become better over time . in addition , the looper/tuner functions are only accessible if you purchase a peavey sanpera pedal . why is this amp not open to 3rd party pedals ? i get that peavey wants to make money , but greater interoperability increases your user base and your income . i am afraid that this amp is stagnant , thus i am going to replace it with a used line 6 or something .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 194:
# Text: i ' ve tried adding tooth pick to the screw holes , no luck . i always have to re-tighten the screws . nice idea , but they don ' t work as well as i ' ve read .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 195:
# Text: good cable . solid soldering and construction .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 196:
# Text: its a cable . . it worked .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 197:
# Text: it is perfect don ' t get me wrong yet it won ' t fit my amp so i had to sell it . make sure it fits your amp first .
# Expected output (Actual label): 2
# Current output (Predicted label): 5
# ------------------------------
# Sample 198:
# Text: order was simple and direct . delivery was on my front porch as promised . price was moderate and fitting for the product . product is of good quality and i am using it every day . good buy for the money !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 199:
# Text: bought these for my ovation acoustic . strings were easy to put on and sound great . will definitely buy these again as needed .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 200:
# Text: smells like pine tree sap , which i think is what it is made of . it really works , but does not easily wash off your fingers . i use it for flat picking .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------

# %% [markdown]
# # Filtered & Balanced

# %%
class_counts = Counter(filtered_labels)
print(class_counts)
# Determine the size of the minority class
min_class_size = min(class_counts.values())

# Define the maximum desired size for each class
max_class_size = min_class_size

# Sample indices for each class to balance the dataset
balanced_indices = []
for label in class_counts:
    indices = [i for i, l in enumerate(filtered_labels) if l == label]
    if len(indices) > max_class_size:
        indices = random.sample(indices, max_class_size)
    balanced_indices.extend(indices)

# Create balanced dataset
filtered_balanced_texts = [filtered_texts[i] for i in balanced_indices]
filtered_balanced_labels = [filtered_labels[i] for i in balanced_indices]
filtered_balanced_dataset = ReviewsDataset(filtered_balanced_texts, filtered_balanced_labels)
filtered_train_balanced_size = int(0.8 * len(filtered_balanced_dataset))
filtered_test_balanced_size = len(filtered_balanced_dataset) - filtered_train_balanced_size
filtered_train_balanced, filtered_test_balanced = random_split(filtered_balanced_dataset, [filtered_train_balanced_size, filtered_test_balanced_size])

filtered_train_balancedloader = DataLoader(filtered_train_balanced, batch_size=32, shuffle=True, collate_fn=collate_fn)
filtered_test_balancedloader = DataLoader(filtered_test_balanced, batch_size=32, shuffle=False, collate_fn=collate_fn)
# Out:
# Counter({5.0: 161798, 3.0: 16029, 1.0: 7465})

# %%
class_counts = Counter(filtered_balanced_labels)
print(class_counts)
# Out:
# Counter({5.0: 7465, 1.0: 7465, 3.0: 7465})

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model5.parameters(), lr=0.001, weight_decay = 1e-5)

num_epochs = 20
model5.train()
for epoch in range(num_epochs):
    all_preds = []
    all_labels = []
    train_loss = 0
    for batch in filtered_train_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        # print(labels)
        optimizer.zero_grad()
        outputs = model5(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = train_loss / len(filtered_train_balancedloader)
    train_accuracy = accuracy_score(all_labels, all_preds)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

# Evaluate the model
model5.eval()
all_preds = []
all_labels = []
test_loss = 0
with torch.no_grad():
    for batch in filtered_test_balancedloader:
        texts = batch[0].to(device)
        labels = batch[1].to(device)
        labels = labels - 1
        outputs = model5(texts)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(filtered_test_balancedloader)
accuracy = accuracy_score(all_labels, all_preds)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/20, Loss: 0.9396, Train Accuracy: 0.5049
# Epoch 2/20, Loss: 0.6077, Train Accuracy: 0.7386
# Epoch 3/20, Loss: 0.4586, Train Accuracy: 0.8171
# Epoch 4/20, Loss: 0.3519, Train Accuracy: 0.8667
# Epoch 5/20, Loss: 0.2520, Train Accuracy: 0.9121
# Epoch 6/20, Loss: 0.1828, Train Accuracy: 0.9388
# Epoch 7/20, Loss: 0.1355, Train Accuracy: 0.9545
# Epoch 8/20, Loss: 0.1150, Train Accuracy: 0.9602
# Epoch 9/20, Loss: 0.0997, Train Accuracy: 0.9665
# Epoch 10/20, Loss: 0.0856, Train Accuracy: 0.9712
# Epoch 11/20, Loss: 0.0786, Train Accuracy: 0.9734
# Epoch 12/20, Loss: 0.0731, Train Accuracy: 0.9746
# Epoch 13/20, Loss: 0.0705, Train Accuracy: 0.9762
# Epoch 14/20, Loss: 0.0660, Train Accuracy: 0.9772
# Epoch 15/20, Loss: 0.0645, Train Accuracy: 0.9772
# Epoch 16/20, Loss: 0.0648, Train Accuracy: 0.9778
# Epoch 17/20, Loss: 0.0589, Train Accuracy: 0.9783
# Epoch 18/20, Loss: 0.0521, Train Accuracy: 0.9824
# Epoch 19/20, Loss: 0.0517, Train Accuracy: 0.9814
# Epoch 20/20, Loss: 0.0555, Train Accuracy: 0.9805
# Test Loss: 1.0626, Test Accuracy: 0.7734

# %%
random_inputs, random_labels = select_random_samples(separated_dataloader, 200)

# Step 3: Prepare the inputs for the model
inputs_tensor = pad_sequence(random_inputs, batch_first=True)
labels_tensor = torch.tensor(random_labels)

# Step 4: Pass the inputs through the model
model5.eval()
with torch.no_grad():
    inputs_tensor = inputs_tensor.to(device)
    outputs = model5(inputs_tensor)

# Step 5: Evaluate the model's performance
predicted_labels = torch.argmax(outputs, dim=1)
def decode_text(numerical_text):
    return ' '.join([vocab.lookup_token(token) for token in numerical_text if token != vocab['<unk>']])

# Print the results for each sample
for i in range(len(random_inputs)):
    decoded_input = decode_text(random_inputs[i])
    print(f"Sample {i+1}:")
    print(f"Text: {decoded_input}")
    print(f"Expected output (Actual label): {labels_tensor[i]}")
    print(f"Current output (Predicted label): {predicted_labels[i]+1}")
    print("-" * 30)
# Out:
# Sample 1:
# Text: good solid feel . price was right and serves the purpose .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 2:
# Text: good
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 3:
# Text: serves the purpose very well and looks awesome in my home studio
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 4:
# Text: i like it a lot . i do wish the it was little longer . i could add my light tripod if it was . i do like the durable quality of the material .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 5:
# Text: it ain ' t fancy , but it does its job well for the price . folk who said it felt flimsy must either be new to mandolin straps or yank pretty hard whether at play or rest . i have an a style mandolin & had to put it on when re-stringing because that ' s the only way to get it in between the strings & headstock . thankfully i expected as much going in , so no loss of stars there . . . doing your homework pays off . when i want to spend $30-60+ on a fine braided leather mandolin strap , that ' s what i do . when i want a perfectly functional strap to do the job without any gripes , this fits the bill quite well .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 6:
# Text: it ' s perfect for what i wanted , the bad thing is that it does not have a power button , it also has a small buzz , but that with all the connected instruments disappears .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 7:
# Text: nothing fancy , but sturdy with good casters . instructions aren ' t great , but are adequate to put this together . all the reviews stating the holes don ' t line up didn ' t read/comprehend the instructions . the reason i knocked off a star is because either the holes weren ' t tapped well or the paint in them made it difficult to thread the screws in . after two difficult ones i got a tap out of the garage and cleaned up all the holes . works great now .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 8:
# Text: need 18v ? have two free 9v outputs ? here you go . good quality cable and connectors . plenty long enough to go the distance on big pedal boards .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 9:
# Text: works fine .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 10:
# Text: definitely good for a pauper . pretty solid product for the money , and seems sturdy enough . i ' m satisfied with the throne initially and put it through it ' s paces , but what matters is how it performs over time . stay tuned sportsfans .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 11:
# Text: a decent capo for the price
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 12:
# Text: good tuner . i have a couple others but i keep going back to this one for some reason . i guess i like the way you can zero in on the note . it doesn ' t fluctuate as much as the others . the display is easy to read even in the dark . all in all a very good tuner .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 13:
# Text: i am still sceptical about these tuners . these are a relatively new design . i haven ' t really road tested them yet , in the context of a show , and if i remember i will amend this review . they ' re grovers , so unless grover has experienced some great dropoff in quality recently , i expect the quality and durability to be good . these were easy to install .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 14:
# Text: this is a great echo pedal . it simulates a tape echo unit , and has some really nice parameters to get that analogue tape sound . you can adjust how ' new ' the tape sounds , and the amount of ' wrinkle ' in the tape . of course there are the usual ' repeats ' & ' time ' functions , but in addition you can specify ' fixed ' , ' multiple ' or ' single ' tape heads . the unit also has onboard reverb , and there are secondary parameters behind four of the knobs , which you can access by holding down the tap and bypass footswitches simultaneously . all parameters can be controlled via an expression pedal , and you can choose between mono and stereo output .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 15:
# Text: nice sticks , just started using them , like the sound
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 16:
# Text: from greg abrams review , entitled for all but the tone snobs , a review further down on this product ' s page alright , so you want to get a good ( if somewhat basic ) distortion sound for less than $100 ? this is your deal . i strongly disagree . you can find much better distortions for $100 or less , even a few near or under the $40 mark the ds-1 is currently priced at . i ' ve played guitar for over 10 years . like many people one of my first pedal purchases was the ds-1 . afterall , everyone talks about them , they ' re available at any given music store in the nation , you hear about all these famous musicians using them , plus a ds-1 is actually pretty cheap ! so i snapped one up just like everyone else . come to find out that just because something is popular , that doesn ' t always mean its good ( see nickelback , the transformers movie franchise , the kardashian family , etc . . . ) . so i plugged it in and didn ' t really care for it . the distortion was harsh , thin , artificial sounding and always noisy . i tried it on both my amps ( my practic amp a solid state fender frontman 25r , and my big amp , the b-52 at100 , which is a 100w tube halfstack ) it was was not very diverse , and the basic sound was not very likeable to me . i ' ve read the japanese made ds-1 ' s are better in sound than the newer , made in taiwan models but , either way , the ds-1 is just not a great pedal in my mind . but , like many newer players , i didn ' t know any better at the time . fast forward a few years and i ' ve bought and sold literally dozens of pedals . there is a whole world of great tones to be found out there if you keep your eyes open . so here are some pedals i currently own that i like much better than the ds-1 . all of them are great general purpose distortions , easy enough to find new and used in most guitar shops , and can , at the time of this writing , be bought brand new for $75 or less here on good ol ' amazon . com , and are rugged enough to last for years <a data-hook=product-link-linked class=a-link-normal href=/boss-ds-2-turbo-distortion/dp/b0002czv8c/ref=cm_cr_arp_d_rvw_txt ? ie=utf8>boss ds-2 turbo distortion</a> lest i catch any flames from people thinking i ' m a boss hater ( i ' m certainly not , i loved the tu-3 , the odb-3 , the md-2 , and the xt-2 , among others ) i ' ll start with the ds-1 ' s big brother . this pedal has a much nicer tone to it , not to mention 2 distinct distortion modes . the i setting is pretty much a higher quality ds-1 , the ii setting is a brighter , richer tone . as the ds-1 completely overshadows the ds-2 in popularity , you can find ds-2 ' s all over ebay for very cheap prices . a very worthy pedal , unfortunately overlooked by many . <a data-hook=product-link-linked class=a-link-normal href=/pro-co-rat2/dp/b0002msqvq/ref=cm_cr_arp_d_rvw_txt ? ie=utf8>pro co rat2</a> great dirty distortion pedal . probably my personal favorite . you ' ve heard this box used on literally hundreds if not thousands of songs in the last 30 years , its used by just a ridiculous amount of guitarists . its a rich , full distortion that at higher gains gets slightly fuzzy . i ' ve never heard a bad tone out of mine . its great for getting a big amp kind of sound out of a small practice amp . its also great for pushing a big amp with too much headroom into the overdriven sweet spot without having to crank the amp volume . a truly excellent pedal . <a data-hook=product-link-linked class=a-link-normal href=/ehx-little-big-muff/dp/b000t517y4/ref=cm_cr_arp_d_rvw_txt ? ie=utf8>ehx little big muff</a> the big muff is another pedal you ' ve heard on hundreds of songs . its kind of a fuzz , kind of a distortion , but definitely owns its own sonic territory . very big , saturated and warm . used heavily in the 70 ' s for classic rock tones , also in the 90 ' s and beyond for tons of grunge and garage . used by everyone from carlos santana and david gilmour to the smashing pumpkins , dinosaur jr . and j ...
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 17:
# Text: i find it a tad bit difficult the remove bridge pins with this tool , but if you put the tool just right , it ' ll work . just requires a bit of practice .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample

# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 43:
# Text: bought as a gift . well packed and quality materials used for its construction .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 44:
# Text: great product for the price . like the retainer pins so you don ' t have to worry about the cheap knob tensioners trying to hold your speakers . great product for someone on a budget .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 45:
# Text: old taylor sounded better with the daddarios
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 46:
# Text: a little thin for great protection , but generally ok for light use . great price , though .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 47:
# Text: good product , comfy strap . pick pocket is kind of meh .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 48:
# Text: please read carefully . i originially purchased this item and it worked great for a while untill i dropped it . i had to get a new one which was not a big deal concidering this price is just so amazingly low . however the second item i got was different . it was very similar so i dealt with it . it also came with a reomote the second time , which was alright . but in order to use the remote you must be within 15 feet and still point directly at the front of the device . also the second item i got was significantly less powerfull . it would lose signal within my car , even though my antenna was only less than 6 feet away . i got so frustrated with this and gave up . i moved away from this device after that . will never buy again .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 49:
# Text: okay products .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 50:
# Text: good quality product .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 51:
# Text: used to own a classic 30 with aftermarket tubes and an old marshall speaker . obviously this doesn ' t hold a candle to a good tube amp , but i do like the range of tones you can achieve with this little guy . bought it as a bridge until i find the direction i want to go with my tone .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 52:
# Text: this is my favorite vocal effects for the price . this review is telling me to use eleven more totally useless words , i have already said what i have to say . i like these fx .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 53:
# Text: works well . well made .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 54:
# Text: the reason for my rating of 4 stars is i evaluated these headphones in 2 different applications -- 5 stars for comfortable sound isolation when recording an instrument in a noisy environment . no , they are not as sound isolating as an in-ear headphone , but they also don ' t give you that music inside your head effect that in-ear monitors give you . 3 stars for sound accuracy . for those who like to mix using headphones , i would caution against using these headphones unless you are comparing to a mix you like the sound of and can then do a side-by-side comparison during the mixing process . why do i say this ? these headphones seem to be a bit heavy in the bass and low mids and seem to have a drop off in treble starting around 6k . this is sometimes a common trait in closed headphones as compared to semi-open . this tends to give a bit boomy and muffled tone . nothing extreme , but they will not have a flat and balanced tone for mixing like classics like the akg 240 headphones or yamaha ns10m studio nearfield monitors . since the story behind these headphones involves them being designed by a drummer , this may explain this tone bias .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 55:
# Text: pros -price point -good , clean audio quality when working . -changeable mesh balls cons -limited upper frequency response ( >8khz ) -one stopped working after about half an hour of use . it was not dropped or abused in any way . -requires nearly direct line of sight between transmitter and receiver for any distance greater than 10 feet .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 56:
# Text: great sound and feel on my acoustic , at least when first installed . they do seem to dull faster than ernie ball strings , hence the 4-star rating . the price is right though for this pack of 3 .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 57:
# Text: bought this for my 13 year old son and the adjustable ease of this is why we love it . he was able to screw everything and adjust it to the perfect fit . love it !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 58:
# Text: it is great !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 59:
# Text: good product )
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 60:
# Text: not the best reading for accuracy
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 61:
# Text: very nice and sturdy bench . very simple to put together , but it ' s kind of a pain keeping the lid open while doing so .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 62:
# Text: works great . no noise and looks good
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 63:
# Text: rating this guitar is a tough call . on the one hand , it has some glaring cosmetic defects . there are places where i am just waiting for the finish to fall off . on the other hand , it sounds absolutely great wether plugged in or all acoustic . all-in-all it is a decent buy for the price . i have no regrets with this purchase .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample
undue stress on the posts , since now only the bridge wings are holding the whole setup to the posts . the one that i received had bent posts from tilting bridge stress , and the threaded inserts had started to loosen in the low quality wood used in this unit . the bridge wings had started to move apart . i was forced to rebuild the insert holes , replace both the inserts and the posts , and reassemble . upon doing this , i found that one of the tuners had suffered a tooth skip , making it unusable for tuning . also , the handles on the keys of the tuners come loose constantly , making it seem like there is a lot of play . possibly putting locktite on the key screws would help . i ' d look for something a little more well built , if you consider yourself a lapsteel player who is concerned for correct tone across the entire board . update , june 2012 just got another one of these in , a shop owner told me i could buy it for $25 , case and all . perfect condition , not a scratch , save the bridge is again doing the same thing . the posts are down in the wood and the bridge is coming up . will make repairs in my shop so it is proper and sell it at a small profit . i ' d stay away from these , just junk .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 87:
# Text: apart from some glitches/issues here and there , it is a wonderful little synth for the price . i could complain about some of the software-related problems , but i paid 299 . 00 for it the price of two solid guitar pedals . the sound on it is rich and very analog . if arturia would improve its support and roll out another firmware update i would be much happier , though .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 88:
# Text: sturdy stand that protects the instrument well . i wish it could fit basses with wider necks . easy operation , sets up and breaks down quickly .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 89:
# Text: i put these in a new bass i built last week . they sound awesome with lots of punch and , they stay clean on the low notes . im impressed with em . the down side would be 1 . the covers are not connected to the pickups and , the adjustment springs support the covers . so , you need to glue the covers on so the weight of the pickup doesn ' t pull loose and fall into the cavity over time . i used clear epoxy and , hoping for the best since i sold the bass when it was finished . on a positive note , the screws and springs were included which was very nice . 2 . the covers have sharper corners than standard precision bass pickups so , if you use a template to route cavities , you ' ll probably have to go back and chisel the corners like i did . im not a fan of that since it doesn ' t look as professional but , i was using a chrome pickup cover so , it worked out . the owner of the bass can ' t say enough about their sound and , i would buy them again .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 90:
# Text: i normally buy gibson mandolin strings , but i decided to give ghs a try . they are made in america and had good reviews . they play good and sound clear and warm , however one of the a strings slowly unwound and popped as i was putting it on ! very disappointed that i had to put one of my old a strings back on to get through a performance the next day . i will not be buying these again .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 91:
# Text: i own the behringer xenyx 1202fx , which is essentially this model but costs about 20 dollars more for the fx ( it comes with 100 set effects ) . i have been doing home recording with cubase and logic , using a presonus firebox audio interface , with both midi , vocals and instruments , and didn ' t use a mixing board , but eventually decided to try one out given that ( a ) they are making them at very reasonable prices and ( b ) i had more inputs and outputs than the firebox could easily handle . this mixing board didn ' t look that impressive to me when i first checked it out , but having set it up and used it , it operates very well and cleanly . the fact that it comes with four mic inputs and preamps is a plus . the fact that it does not have an on/off switch is a minus . but basically it works well , the eq is useful , and it has a large number of inputs and outputs for such a small mixer . behringer makes a range of models with less/more inputs to suit one ' s needs , so this is great . also , having a dedicated mixer makes it easier for me , as i can leave all my inputs connected and just adjust things on the mixer depending on what i want to record . another small thing that is mixing is a button that cuts out the line altogether -- you have to turn it down to zero . and , there are no faders ( except the main ) instead it uses knobs for everything . well , i would have liked some of these things , but then i would have to pay more , and what i really wanted was functionality at a good price , and that is what the behringer xenyx has delivered thus far . by the way , i am running the following through the mixer an at3035 audiotechnica condenser mic , an alesis qs8 . 1 , guitar via line-in ( or mic ' d ) , two krk rp5 studio monitors , presonus firebox . everything ' s been working and sounding great thus far . since i ' m using logic , the effects are basically unnecessary , but if i ever want to use the board for live use , which i may do , they could come in handy . i ' d say the effects are just so-so .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 92:
# Text: please keep in mind that these chauvet 700 dj fog machines have a hard wired manual control only controller . you cannot use a timer control on these . this was my fault for overlooking this in the product description . the reason for the low review is . . . i bought 2 of these and seen that they do not heat evenly from unit to unit . thermal protection does not allow them to operate until cooled down , thus i was not able to have fog on demand when desired . i will figure out a way around this but i just expected a more uniform product from chauvet .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 93:
# Text: these are exactly what i expected and work fine , but what i didn ' t realize is that pedals from different brands have their jacks at different heights so these don ' t work for all my pedals . this is not a fault of the product , however , just something easy for consumers to overlook .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 94:
# Text: very flimsy . not what i expected .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 95:
# ...
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 169:
# Text: well packed and seem well-built !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 170:
# Text: way too bulky .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 171:
# Text: while i ' ll be the first to admit that i ' m a bit biased and that i really don ' t care for gimmicks as i ' ve seen many come and go , however after having recently tried these strings i have to honestly say - i ' m just not impressed . the only thing i can assume is that since these typically cost 2 - 3 times more than traditional strings , some people apparently assume they must somehow be better . . . after all , if it costs more , it must be better . . . right ? not always . . . . . . first and foremost , i ' ll address the sound . . . after all , that is the single greatest factor regarding a guitar string . while longevity and playability are important factors , if a guitar string doesn ' t sound good , the other two issues are pretty meaningless . i recently played these strings on both a martin , as well as on a seagull to provide a fair and objective comparison , to my ear , right out of the box they sound very artificial , if not acoustically dead . . . these just don ' t have the sparkle that you would expect from a more traditional acoustic guitar string . the nearest i can figure is that the coating prevents the string from vibrating correctly . . . it seems to dampen the rich harmonic overtones you would normally associate with a vibrating guitar string , much the way dirt and rust do on older strings . i suspect there are folks who prefer this to the rich , lively , vibrant sound of fresh strings , however i don ' t . as a person who plays very regularly ( often as much as 2 -3 hours per day or more when i ' m gigging ) , i do change my strings often and the sound of a fresh , traditional guitar string is just much more appealing . very simply , even if these strings were more realistically priced , i would not use them again based on this issue alone . likewise , while some folks seem to like the feel of these strings , i didn ' t . perhaps it ' s simply that i play regularly enough that my calluses are built up to the point that regular guitar strings don ' t bother me ( it should go with the turf ) . possibly its a result of my playing both electrics and acoustics on a regular basis and it could simply even be the number of years i ' ve been playing ( well over 30 as of this writing ) and that i ' m just very used to traditional guitar strings . regardless , personally i found the feel of these strings to be rather distracting . . . they just don ' t feel like guitar strings to my fingers . i suspect that if these were the only guitar strings available , given time i would eventually get used to the feel , however i simply found myself thinking more about how annoying they were than i did about my playing . . . not a good thing for a performing musician . in fairness , i can ' t speak much to the longevity of these strings as they were removed and replaced with a set of ernie ball earthwood ' s after only a few days ( 2 sets of elixirs around $15 a pop . . . yea - serious waste of money there ) . while it seems most unlikely , it could be possible that these somehow improve with age , perhaps as that coating wears off . . . but i doubt it . either way , i can ' t provide any details as to how long they might last under normal playing conditions . . . . i just couldn ' t force myself to put up with them that long to find out . as with so many things related to guitars ( or music as a whole ) , guitar strings are of course , a very personal choice and everyone has their own tastes and preferences . in my many years as a musician , i ' ve probably played every brand of guitar string out there at one point or another and certainly there are some brands that i do very much tend to favor ( such as ghs boomers for my electrics ) . with that in mind , i can ' t see these elixir strings as anything but a gimmick . . . between the poor sound , the annoying feel and the truly exorbitant price , seriously . . . i ' ll stick with ernie balls .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 172:
# Text: perfect !
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 173:
# Text: good value . work just fine for live rigs .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 174:
# Text: it ' s fine . just what i needed .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 175:
# Text: good deal for the money .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 176:
# Text: my guitar string of choice
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 177:
# Text: reminiscent of the od 1930 ' s - ' 40 ' s ribbon mics . you need a shock mount for this since any vibration in the floor or mic stand will come through on the mic .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 178:
# Text: i only give it four stars , because i have not had enough experience with it yet . i am working on my first original music cd release . it gives me good control and is a seamless interface with my digital audio workstation ( daw ) . i use cakewalk sonar for my recording and engineering , after notating in noteworthy composer music software . i use multiple microphones to record live instruments on background virtual instruments . i like the sound quality . i like that i can add effects as i record , although right now i prefer adding them post recording . i am still learning its utility which i know is far more than i have exploited in the short time i have had it ( less than three months ) . i like the effectiveness of the equalizer feature . i am still learning what the compressor does . i know it is important . again , this is why i give it four stars , but fully expect to upgrade to five stars .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 179:
# Text: good mic stand , it seems to be sturdy enough . although with the cad m179 it does seem a little tipsy , not a very strong base . nothing bad has happened yet though , i take care of my stuff .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 180:
# Text: it ' s ok but not great for drummers at the kit . it is not loud enough and the headphone jack only transmits on the left channel . - booo ! there could also be more sounds to choose from , as they all seem to lack a little . when dialing down the tempo the metronome actually speeds up briefly which is annoying . this is a rushed design and not a great bang . there are much smaller and cheaper metronomes that do better than this huge clunker . the only cool thing is the flashing knob on top .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 181:
# Text: nice cheap replacement set . they are a generic cut though . to make thiese have a perfect fit to your guitar would take hours of measuring sanding/fitting to your fretboard . bridge pins have a nice feel . i would suggest just paying a professional to do replacement work like this . if you are that professional these are a good buy .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 182:
# Text: nice warm sound .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 183:
# Text: i purchased one of these to use at work to upgrade the first generation usb pro system that arrived with 8 pads . ( though i ' m pretty sure i ordered the 10 ones . ) the 8 pads were just too uncomfortable to use in the frequency we are tracking . it caused us , to have to focus more on hitting targets than performing the tracks for production . i added one of these 10 pads for one rack tom keeping an 8 for the highest tom and adding two 12 pads for one rack tom and floor tom , everything feels more natural now ! the only reason for the 4 stars is , the pads seem to be made of a cheap plastic that could break under heavy use . in our situation , we get some heavy hitters sometimes . it isn ' t an issue for general consumer use unless you are a hard hitter .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 184:
# Text: very cheaply made , fimsy .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 185:
# Text: decent quality . cheap price . we ' ll see how long it lasts . but , for now , does the trick . i think the odds of be becoming rich and famous have increased because of this stand .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 186:
# Text: good but not perfect . i ' ve been experimenting with the many brands/sizes of guitar strings so i ' ve done a lot of tuning . there ' s a tuning app for my phone that i ' ve also used to double-check the accuracy . the app and this little tuner are in great agreement , even when the tuning is high or low by only a small amount ( about 1-2 bars ) . my only complaint is that it can have trouble during sustain , especially towards the midpoint . sometimes i ' ll see wild fluctuations and know i need to pluck the string again even though i can still clearly hear the sound ( this works from vibration though ) but sometimes it ' s more subtle and i find i ' ve tuned too far when i pluck again . note i ' m still a beginner with guitars . if it turns out this sustain-accuracy issue is common to clip-on tuners , please let me know and i ' ll upgrade the rating to 5 stars .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 187:
# Text: these are good little tuners for the price . the rubber grips are adequate and the read out is reasonably bright . they tend too get ' confused ' and not display the correct note on occasion , hence the 4 star rating . i did buy quite a few , since i perform with a number of guitars and ukeleles , and at this price , each instrument has its own dedicated tuner .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 188:
# Text: good clip-on tuner
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 189:
# Text: for the money , you can ' t beat this delay pedal . i needed a nice delay for my back-up board and didn ' t want to spend the big bucks that most delay pedals cost . i won ' t disparage other brands , but this delay has since replaced the other one to be on my main board . now for the update , it has completely died . not worth taking apart and fixing . i ' m done buying the budget brands and going to stick to the better products .
# Expected output (Actual label): 2
# Current output (Predicted label): 3
# ------------------------------
# Sample 190:
# Text: ok .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 191:
# Text: great gift
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 192:
# Text: works good
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 193:
# Text: it doesn ' t say low g here or on the package<a data-hook=product-link-linked class=a-link-normal href=/aquila-new-nylgut-aq-16-tenor-ukulele-string-low-g-4th-string/dp/b00mxuin9u/ref=cm_cr_arp_d_rvw_txt ? ie=utf8>aquila new nylgut aq-16 tenor ukulele string - low g - 4th string</a> . the string looks just like the high g string that ' s already on my ukulele . i left a question of whether it should say low g on the package , but i ' m not getting a quick enough response so i ' m returning it .
# Expected output (Actual label): 2
# Current output (Predicted label): 1
# ------------------------------
# Sample 194:
# Text: i will agree with some of the other reviews that this is a poor choice for the bright el84 driven blues jr , but in general i don ' t care for the blues jr . the wizard really busts out some sound in a closed back cab though , and is a semi bright sounding speaker to my ears . my jcm 800 clone through my wizard in a closed back alpha pup has some serious tight low end . a 15 watt amp could certainly extend it ' s reach with this high efficiency speaker . i ' m still breaking in my wizard , but it seems pretty good so far . i think i prefer american voiced speakers though .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 195:
# Text: there ' s a lot of junk guitars in the low end or student market , that ' s for sure . aside from the sea of chinese copies of stratocasters , there are a few good guitars out there- but good luck finding them . the dean vendetta is a refreshing change from all the fake stratocasters out there . it ' s more versatile than a strat as far as what sounds you can get from it and the fact that it doesn ' t look like every other guitar is a bonus . comparing to the other guitar of note in this price range- the squier stratocaster- i would have to give the nod to the vendetta . it ' s lighter , it ' s more versatile from country to metal- and it really kills on metal- it ' s pretty much better in every way than the squier . start comparing it to guitars over $300 and it will show its limitations . . . but then again there are high end vendettas too . i have one of those too , hanging next to my gibson lp and us strat . the vendetta holds its own . i was originally turned on to these by bret michael ' s guitar player and producer- who plays a custom vendetta .
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 196:
# Text: good quality and shipped very quickly . installed easily . only negative is it also amplifies all sounds such as when your fingers rub the top of the guitar when you are playing . i am going to change to an under saddle pickup .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 197:
# Text: perfect fit for kala ka-be mahogany baritone ukulele with eq . great for travel and storage . fair quality for cost of bag .
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 198:
# Text: i heard good things , so since i was selling the drums , i gave these a try . i didn ' t expect they would sound like evans pinstripes , and they don ' t , but , they really have a pretty good sound . they tune easily , seat well , and for the price , they sound great ! pretty shocking really . i ' ve spent allot more money on heads that sounded much worse . good bounce , good sound , and strong . i ' m not sure i ' d buy these for the studio , but you could do allot worse , and for a allot more money . i bought another set as back up heads to my touring set . nice deal , well done !
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------
# Sample 199:
# Text: good harmonica
# Expected output (Actual label): 4
# Current output (Predicted label): 5
# ------------------------------
# Sample 200:
# Text: they work as expected
# Expected output (Actual label): 4
# Current output (Predicted label): 3
# ------------------------------

# %% [markdown]
# # IMDB Loading

# %%
imdb = pd.read_csv('IMDB Dataset.csv')

# %%
imdb.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
texts = imdb['review'].tolist()
labels = imdb['sentiment'].tolist()
texts = [text_pipeline(text) for text in texts]
label_map = {"negative": 0, "positive": 1}
labels = [label_map[label] for label in labels]
imdb_dataset = ReviewsDataset(texts, labels)
imdb_dataloader = DataLoader(imdb_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)
random_inputs, random_labels = select_random_samples(imdb_dataloader, 200)
inputs_tensor = pad_sequence(random_inputs, batch_first=True)
labels_tensor = torch.tensor(random_labels)

# %% [markdown]
# # Unbalanced IMDB

# %%
model4.eval()
with torch.no_grad():
    inputs_tensor = inputs_tensor.to(device)
    outputs = model4(inputs_tensor)

# Step 5: Evaluate the model's performance
predicted_labels = torch.argmax(outputs, dim=1)
for i in range(len(random_inputs)):
    decoded_input = decode_text(random_inputs[i])
    actual_label = "positive" if labels_tensor[i].item() == 1 else "negative"
    print(f"Sample {i+1}:")
    print(f"Text: {decoded_input}")
    print(f"Expected output (Actual label): {actual_label}")
    print(f"Current output (Predicted label): {predicted_labels[i].item()}")
    print("-" * 30)
# Out:
# Sample 1:
# Text: the film is about the battle of . for those of you who don ' t know anything about it , it was the worst battle in the second world war . over 1 million people died in the course of the battle . this is the only film that i ' ve seen that seems to have actually captured how bad things were in the war between russia and germany . what i really liked about it is that the two ( and communism ) were nowhere in the film . unlike most american films , the germans are not seen as blood thirsty , but what the average german foot soldier was , a person . the film around four soldiers fighting in . they were transferred there to try and take the city . the film follows these men from august of to early 1943 . during this time , they learn about the horrors of war and try to find a way out of the battle . through the entire film , one feels the desperation of the entire battle . unlike enemy at the gates the film makers didn ' t try to put some sappy love story or dress up occurrences of the battle . this film may be fiction , but it conveys what happened in the battle in world war ii .
# Expected output (Actual label): positive
# Current output (Predicted label): 4
# ------------------------------
# Sample 2:
# Text: this production has it ' s fans . but to paraphrase the classic bad review of ' mary reilly , ' moby dick is like a painting , only slower . this is because the philosophical grounds for a movie production are never to make a great film , rather it ' s to substitute the lack of a strong guiding idea ( in this case for a books transference to film ) with a list of hopelessly , but dazzling in an effort to trick viewers into thinking they ' ve seen greatness . as viewers & critics are apt to fall for this , oscars follow , feeding the whole dumb equation . i don ' t share in the pleasure all these reviewers found . moby dick is stunningly . actors dutifully essays about , moby dick , the ocean , moby dick , moby dick . . . all things that can ' t respond , and not one of which is absorbing in the slightest . it ' s dramatically inert . it doesn ' t build . in narrative terms moby dick ( as a movie ) is little more than a conclusion in search of an actual story . after half an hour i was oh terrific . . . another . . . another 4 minute ! in the failed effort to involve you , it ' s a pretty campy showcase . a lot of grey hair here . starbuck is supposed to be a golden god . ( ! ) one knows one is looking at a great director when he makes the medium his own rather than trying to replicate the feel of someone else ' s paintings & palette , or a classic as does here . paintings and books are nice but they ' re a different mediums . a movie like this fails to grasp that an honestly enjoyable piece of crap ( village of the damned ) is better in most respects than an insufferable piece of culture . this is the eat your vegetables school of . one appreciates the work that must have been done to make the movie , but not the narrative . only a few segments reflecting maritime research are interesting the recording of as a means of work & various sea efforts and the technology of whaling . and that doesn ' t call for a hour movie .
# Expected output (Actual label): negative
# Current output (Predicted label): 4
# ------------------------------
# Sample

# Expected output (Actual label): negative
# Current output (Predicted label): 4
# ------------------------------

# %% [markdown]
# # Balanced IMDB

# %%
model5.eval()
with torch.no_grad():
    inputs_tensor = inputs_tensor.to(device)
    outputs = model5(inputs_tensor)

# Step 5: Evaluate the model's performance
predicted_labels = torch.argmax(outputs, dim=1)
for i in range(len(random_inputs)):
    decoded_input = decode_text(random_inputs[i])
    actual_label = "positive" if labels_tensor[i].item() == 1 else "negative"
    print(f"Sample {i+1}:")
    print(f"Text: {decoded_input}")
    print(f"Expected output (Actual label): {actual_label}")
    print(f"Current output (Predicted label): {predicted_labels[i].item()}")
    print("-" * 30)
# Out:
# Sample 1:
# Text: the film is about the battle of . for those of you who don ' t know anything about it , it was the worst battle in the second world war . over 1 million people died in the course of the battle . this is the only film that i ' ve seen that seems to have actually captured how bad things were in the war between russia and germany . what i really liked about it is that the two ( and communism ) were nowhere in the film . unlike most american films , the germans are not seen as blood thirsty , but what the average german foot soldier was , a person . the film around four soldiers fighting in . they were transferred there to try and take the city . the film follows these men from august of to early 1943 . during this time , they learn about the horrors of war and try to find a way out of the battle . through the entire film , one feels the desperation of the entire battle . unlike enemy at the gates the film makers didn ' t try to put some sappy love story or dress up occurrences of the battle . this film may be fiction , but it conveys what happened in the battle in world war ii .
# Expected output (Actual label): positive
# Current output (Predicted label): 0
# ------------------------------
# Sample 2:
# Text: this production has it ' s fans . but to paraphrase the classic bad review of ' mary reilly , ' moby dick is like a painting , only slower . this is because the philosophical grounds for a movie production are never to make a great film , rather it ' s to substitute the lack of a strong guiding idea ( in this case for a books transference to film ) with a list of hopelessly , but dazzling in an effort to trick viewers into thinking they ' ve seen greatness . as viewers & critics are apt to fall for this , oscars follow , feeding the whole dumb equation . i don ' t share in the pleasure all these reviewers found . moby dick is stunningly . actors dutifully essays about , moby dick , the ocean , moby dick , moby dick . . . all things that can ' t respond , and not one of which is absorbing in the slightest . it ' s dramatically inert . it doesn ' t build . in narrative terms moby dick ( as a movie ) is little more than a conclusion in search of an actual story . after half an hour i was oh terrific . . . another . . . another 4 minute ! in the failed effort to involve you , it ' s a pretty campy showcase . a lot of grey hair here . starbuck is supposed to be a golden god . ( ! ) one knows one is looking at a great director when he makes the medium his own rather than trying to replicate the feel of someone else ' s paintings & palette , or a classic as does here . paintings and books are nice but they ' re a different mediums . a movie like this fails to grasp that an honestly enjoyable piece of crap ( village of the damned ) is better in most respects than an insufferable piece of culture . this is the eat your vegetables school of . one appreciates the work that must have been done to make the movie , but not the narrative . only a few segments reflecting maritime research are interesting the recording of as a means of work & various sea efforts and the technology of whaling . and that doesn ' t call for a hour movie .
# Expected output (Actual label): negative
# Current output (Predicted label): 0
# ------------------------------
# Sample